# %%
#펭수/워크맨 csv 불러와서 시각화 및 머신러닝
# 패키지 import
import datetime as dt
import pandas as pd   #df 분석용
import requests
import time
import urllib.request #
import re     
import konlpy

from bs4 import BeautifulSoup
from pandas import DataFrame
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from nltk import FreqDist

# %%
# 시각화  
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from PIL import Image             #워드클라우드용
from wordcloud import WordCloud   #워드클라우드용
fpath = "NotoSansCJKkr-Bold.otf"   #워드클라우드 국문지원을 위한 별도 폰트 path 설정
# %matplotlib inline

# 기계 학습
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_extraction.text import CountVectorizer

# %%
############### Read #################
peng_intro = pd.read_csv('peng_intro.csv')  # 펭수의 intro DF 
work_intro = pd.read_csv('work_intro.csv')  # 워크맨의 intro DF 

peng = pd.read_csv('peng.csv')               #펭수의 동영상list DF
peng_reply = pd.read_csv('peng_reply.csv')   #펭수의 동영상별 댓글list DF

work = pd.read_csv('work.csv')               #워크맨의 동영상list DF
work_reply = pd.read_csv('work_reply.csv')   #워크맨의 동영상별 댓글list DF

############# 구분자 추가 ################
for i in range(len(peng)): peng['구분'] = '펭수' 
for i in range(len(work)): work['구분'] = '워크맨'
for i in range(len(peng_reply)): peng_reply['구분'] = '펭수'    
for i in range(len(work_reply)): work_reply['구분'] = '워크맨'
    
############## DF 통합 ##################
# 1) 펭수 + 워크맨 intro DF 통합
intro_paw = pd.DataFrame(peng_intro)       
intro_paw = intro_paw.append(work_intro)

# 2) 펭수 + 워크맨 동영상list DF 통합
paw = pd.DataFrame(peng)     
paw = paw.append(work)

# 3) 펭수 + 워크맨 동영상별 댓글list DF 통합
paw_reply = pd.DataFrame(peng_reply)  
paw_reply = paw_reply.append(work_reply)

# %%
intro_paw.head()
# Out:
#    Unnamed: 0   구분    구독자  영상수
# 0           1   펭수  135만명  133
# 0           2  워크맨  353만명   35

# %%
paw = paw.astype({'좋아요': int})
paw.head()  #  통합한 동영상list DF 확인
# Out:
#    Unnamed: 0                                   제목                    주소  \
# 0           0       [Ep 67] 전 세계 게 섰거라 (feat. 외교부)  /watch?v=yUJAvW2Rykc
# 1           1                    [Ep.66]  화보 모델 펭수  /watch?v=XUM3sH1kBtw
# 2           2  펭수와 팬들의 최강 컬래버레이션 신상뮤비 (feat. 챌린지♡)  /watch?v=LPmyxMH96S8
# 3           3               [Ep.65] 세상에 나쁜 펭귄은 없다.  /watch?v=wedLGh2jxkQ
# 4           4    수험생은 지금 당장 이 영상을 봅니다 (feat. 정승제쌤)  /watch?v=25RhzK3HuYM
#
#          조회수    좋아요  싫어요    댓글수  \
# 0  1,381,698  42000  749  6,838
# 1  1,583,971  46000  455  7,678
# 2    604,376  29000  135  3,921
# 3  1,975,593  50000  548  6,974
# 4    651,078  20000  135  2,760
#
#                                                 본문내용  구분
# 0                                       K-펭귄 한다 해외진출  펭수
# 1  펭수가 화보 모델로서 촬영을 하게 되었다!화보 촬영을 위한 펭수의 눈물(?) 나는 ...  펭수
# 2  힙합펭수의 커버영상이 드. 디. 어. 찾아왔다!월미도에서 촬영했던 미공개 영상과 여...  펭수
# 3  어느 날 갑자기 펭수에게 이상한 행동들이 보인다!? 걱정된 제작진들이 긴급 솔루션 ...  펭수
# 4            내일 모레 엄청 큰 시험을 앞둔여러분들을 위해 이 영상을 바칩니당 펭펭  펭수

# %%
paw_reply.describe()  # 통합한 동영상별 댓글list DF 확인
# Out:
#         Unnamed: 0          Like  Title_number
# count  3160.000000   3160.000000        3160.0
# mean      9.500000   1430.986392           0.0
# std       5.767194   2652.356452           0.0
# min       0.000000      0.000000           0.0
# 25%       4.750000    193.000000           0.0
# 50%       9.500000    546.500000           0.0
# 75%      14.250000   1500.000000           0.0
# max      19.000000  38000.000000           0.0

# %%
paw.describe()
# Out:
#        Unnamed: 0            좋아요          싫어요
# count  158.000000     158.000000   158.000000
# mean    51.253165   29989.873418   467.550633
# std     36.693070   32530.949869   685.085234
# min      0.000000    2400.000000     8.000000
# 25%     19.250000    9925.000000    69.250000
# 50%     43.500000   17500.000000   163.500000
# 75%     82.750000   35750.000000   464.750000
# max    122.000000  180000.000000  3600.000000

# %%
intro_paw.describe()
# Out:
#        Unnamed: 0         영상수
# count    2.000000    2.000000
# mean     1.500000   84.000000
# std      0.707107   69.296465
# min      1.000000   35.000000
# 25%      1.250000   59.500000
# 50%      1.500000   84.000000
# 75%      1.750000  108.500000
# max      2.000000  133.000000

# %%
#시각화
fig = plt.figure(figsize=(20,5))
plt.title('가장 많은 좋아요 순 정렬')
sns.barplot(x='제목', y='좋아요', data=paw[['제목', '좋아요']].groupby('제목', as_index=False).mean().sort_values(by='좋아요', ascending=False))[10];
plt.xticks(rotation=90); #x축(country) 회전

# 구분에 따른 요약
paw[['좋아요','구분']].groupby('구분', as_index=False).mean().sort_values(by='좋아요', ascending=False).head()
# Out:
#   File "<ipython-input-27-13de0c26d4e6>", line 4
#     sns.barplot(x='제목', y='좋아요', data=paw[['제목', '좋아요']].groupby('제목', as_index=False).mean().sort_values(by='좋아요', ascending=False));[:10]
#                                                                                                                                        ^
# SyntaxError: invalid syntax

# %%
############ UNLIKE RATIO 구하기 ############  
# 워킹맨 구독자 수가(353만명) 펭수(134만명)의 3배이상으로, 
# 비율을 구해 서로의 값을 확인 예정

unlike_ratio_list = []
for i in range(len(paw)): 
    unlike_ratio = (paw.iloc[i, 5] / paw.iloc[i,4]) * 100  # 퍼센테이지 표현
    unlike_ratio_ar= round(unlike_ratio,2)                 # 소숫점 2자리까지 표현 
    unlike_ratio_list.append(unlike_ratio_ar)          

paw['unlike_ratio(%)'] = unlike_ratio_list                 # ratio 열 생성

# %%
paw.head()
# Out:
#    Unnamed: 0                                   제목                    주소  \
# 0           0       [Ep 67] 전 세계 게 섰거라 (feat. 외교부)  /watch?v=yUJAvW2Rykc
# 1           1                    [Ep.66]  화보 모델 펭수  /watch?v=XUM3sH1kBtw
# 2           2  펭수와 팬들의 최강 컬래버레이션 신상뮤비 (feat. 챌린지♡)  /watch?v=LPmyxMH96S8
# 3           3               [Ep.65] 세상에 나쁜 펭귄은 없다.  /watch?v=wedLGh2jxkQ
# 4           4    수험생은 지금 당장 이 영상을 봅니다 (feat. 정승제쌤)  /watch?v=25RhzK3HuYM
#
#          조회수    좋아요  싫어요    댓글수  \
# 0  1,381,698  42000  749  6,838
# 1  1,583,971  46000  455  7,678
# 2    604,376  29000  135  3,921
# 3  1,975,593  50000  548  6,974
# 4    651,078  20000  135  2,760
#
#                                                 본문내용  구분  unlike_ratio(%)
# 0                                       K-펭귄 한다 해외진출  펭수             1.78
# 1  펭수가 화보 모델로서 촬영을 하게 되었다!화보 촬영을 위한 펭수의 눈물(?) 나는 ...  펭수             0.99
# 2  힙합펭수의 커버영상이 드. 디. 어. 찾아왔다!월미도에서 촬영했던 미공개 영상과 여...  펭수             0.47
# 3  어느 날 갑자기 펭수에게 이상한 행동들이 보인다!? 걱정된 제작진들이 긴급 솔루션 ...  펭수             1.10
# 4            내일 모레 엄청 큰 시험을 앞둔여러분들을 위해 이 영상을 바칩니당 펭펭  펭수             0.68

# %%
# unlike에 따른 정렬 및 시각화
peng_list=[]  # 현재 df가 통합되어, 색상 분리를 위해 다시 분리
work_list=[]

for i in range(len(paw)):        
    if (paw.iloc[i,8]) =='펭수':   # '구분'이 펭수일 경우
        peng=paw.iloc[i,9]         # 펭수의 ratio를 peng_list에 삽입
        peng_list.append(peng)
    else:
        work=paw.iloc[i,9]         # '구분'이 워크맨일 경우 
        work_list.append(work)     # 워크맨의 ratio를 work_list에 삽입

plt.plot(peng_list, marker='.', color='b')   # 펭수: blue
plt.plot(work_list, marker='.', color='r')   # 워크맨: red
plt.legend(['워크맨', '펭수'], loc='upper right')

# 구분에 따른 요약
paw[['unlike_ratio(%)','구분']].groupby('구분', as_index=False).mean().sort_values(by='unlike_ratio(%)',
                                                                               ascending=False).head()
# Out:
#     구분  unlike_ratio(%)
# 0  워크맨         1.901143
# 1   펭수         1.007561
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54189 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50892 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 53356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54189 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\백송이\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 워드 클라우드 설정
title_l2s=(''.join(paw["제목"])) # paw의 제목df를 string으로

image_test=np.array(Image.open("ytbb.png")) #mask 이미지 설정
wc = WordCloud(max_font_size=200,font_path=fpath,background_color='#FFFFFF',
               width=1200,height=800,mask=image_test).generate(title_l2s)

#사이즈 등 설정
plt.figure(figsize=(10,8))
plt.imshow(wc)
plt.tight_layout(pad=0)
plt.axis('off')
# Out:
# (-0.5, 799.5, 799.5, -0.5)

# %%
total_cnt = len(paw_reply['ID'])
cnt_1percent= total_cnt*0.01
print("* 전체 댓글 개수:", len(paw_reply['ID']), ", 전체 댓글의 1% 개수:", cnt_1percent)
print("/////////////////////////////////////////////////////////////////////////////")
print("* 상위 10% User ID 빈도수 확인(count):")
print(paw_reply['ID'].value_counts(ascending=False)[:31]) # 빈도수 기준 내림차순

print("/////////////////////////////////////////////////////////////////////////////")
print("* 상위 10% User 빈도수 확인(ratio):")
print(paw_reply['ID'].value_counts(normalize=True)[:31])  # 비율 기준 출력
# Out:
# * 전체 댓글 개수: 3160 , 전체 댓글의 1% 개수: 31.6
# /////////////////////////////////////////////////////////////////////////////
# * 상위 10% User ID 빈도수 확인(count):
#  자이언트 펭TV                         40
#  워크맨-Workman                      34
#  나눈누                              16
#  Jeje                             15
#  고잉메리쓰                            11
#  펭랑단1호                            10
#  펭수쳐돌이                             9
#  펭펭                                8
#  SAJOgroup                         7
#  오석현                               7
#  JE Choi                           6
#  콩절미                               6
#  ᄋᄋ                                6
#  지금이순간                             6
#  9 cw                              6
#  유달별                               5
#  김명중                               5
#  인사처TV                             5
#  공인회계사50th                         5
#  둘기                                5
#  반현정                               5
#  So So                             5
#  Amber Rodriguez                   5
#  The great Peng                    5
#  민트마카롱                             5
#  오하라                               5
#  polarin                           5
#  yeanjung yoo                      5
#  Uu                                4
#  쟝글렛                               4
#  ji min                            4
# Name: ID, dtype: int64
# /////////////////////////////////////////////////////////////////////////////
# * 상위 10% User 빈도수 확인(ratio):
#  자이언트 펭TV                         0.012658
#  워크맨-Workman                      0.010759
#  나눈누                              0.005063
#  Jeje                             0.004747
#  고잉메리쓰                            0.003481
#  펭랑단1호                            0.003165
#  펭수쳐돌이                            0.002848
#  펭펭                               0.002532
#  SAJOgroup                        0.002215
#  오석현                              0.002215
#  JE Choi                          0.001899
#  콩절미                              0.001899
#  ᄋᄋ                               0.001899
#  지금이순간                            0.001899
#  9 cw                             0.001899
#  유달별                              0.001582
#  김명중                              0.001582
#  인사처TV                            0.001582
#  공인회계사50th                        0.001582
#  둘기                               0.001582
#  반현정                              0.001582
#  So So                            0.001582
#  Amber Rodriguez                  0.001582
#  The great Peng                   0.001582
#  민트마카롱                            0.001582
#  오하라                              0.001582
#  polarin                          0.001582
#  yeanjung yoo                     0.001582
#  Uu                               0.001266
#  쟝글렛                              0.001266
#  ji min                           0.001266
# Name: ID, dtype: float64

# %%
# csv 파일의 columnms 확인
paw.columns
paw_reply.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Comment', 'Like', 'Title_number', '구분'], dtype='object')

# %%
# csv 파일에서 필요한 column만 리스트로 저장
paw_title_list = paw.제목.tolist()
paw_content_list = paw.본문내용.tolist()
paw_reply_list = paw_reply.Comment.tolist()

# %%
# 리스트 출력하여 확인
print(paw_title_list[:3])  #부하로 인해 테스트로 3개만 출력
# Out:
# ['[Ep 67] 전 세계 게 섰거라 (feat. 외교부)', '[Ep.66]  화보 모델 펭수', '펭수와 팬들의 최강 컬래버레이션 신상뮤비 (feat. 챌린지♡)']

# %%
# 형태소 분석
from konlpy.tag import Okt
okt=Okt()

# %%
# 제목 리스트 명사 분석
title_list=[]
for i in range(len(paw_title_list)):
    title_list.append(okt.nouns(paw_title_list[i]))
    
# 본문 내용 명사 분석
content_list=[]
for i in range(len(paw_content_list)):
    content_list.append(okt.nouns(paw_content_list[i]))

# 댓글 내용 명사 분석
reply_list=[]
for i in range(len(paw_reply_list)):
    reply_list.append(okt.nouns(paw_reply_list[i]))

# %%
# 리스트 안의 리스트 하나의 리스트로 만들기
def flatten (n):
    org =[]
    for i in n :
        if (isinstance(i,list)):
            org += flatten(i)
        else:
            org.append(i)
    return org

# %%
flatten(title_list) # 실행되는지 확인
# Out:
# ['전',
#  '세계',
#  '게',
#  '외교부',
#  '화보',
#  '모델',
#  '펭수',
#  '펭수',
#  '팬',
#  '최강',
#  '컬래버레이션',
#  '신상',
#  '뮤비',
#  '린지',
#  '세상',
#  '펭귄',
#  '수험생',
#  '지금',
#  '당장',
#  '이',
#  '영상',
#  '정승',
#  '쌤',
#  '남극',
#  '유치원',
#  '동창회',
#  '시작',
#  '둘리',
#  '선배',
#  '등장',
#  '윤도현',
#  '선배',
#  '본부',
#  '만남',
#  '우리',
#  '호흡',
#  '난리',
#  '남',
#  '펭수',
#  '매니저',
#  '사관학교',
#  '매니저',
#  '스',
#  '펭',
#  '인간',
#  '펭귄',
#  '첫',
#  '데이트',
#  '펭수',
#  '실버',
#  '버튼',
#  '날개',
#  '언박싱',
#  '처음',
#  '나',
#  '펭수',
#  '학교',
#  '잠입',
#  '공',
#  '행운',
#  '펭수',
#  '카드',
#  '탄생',
#  '비화',
#  '개',
#  '펭수',
#  '퇴사',
#  '정복기',
#  '이제야',
#  '공개',
#  '추억',
#  '라이브',
#  '진행',
#  '펭',
#  '펭수',
#  '관심사',
#  '대결',
#  '정복기',
#  '친구',
#  '간다',
#  '펭수',
#  '비밀',
#  '펭귄',
#  '극장',
#  '스타',
#  '외로워',
#  '한류',
#  '펭귄',
#  '펭수',
#  '해외진출',
#  '프랑스',
#  '편',
#  '추억',
#  '독자',
#  '축하',
#  '라이브',
#  '트렌치코트',
#  '언박싱',
#  '단독',
#  '펭귄',
#  '의혹',
#  '전격',
#  '해부',
#  '독점',
#  '인터뷰',
#  '김민교',
#  '양치',
#  '승',
#  '펭수',
#  '진짜',
#  '나이',
#  '살',
#  '펭귄',
#  '극장',
#  '내',
#  '나이',
#  '자이언트',
#  '펭',
#  '방송',
#  '시간',
#  '변경',
#  '안내',
#  '펭',
#  '야유회',
#  '지옥',
#  '신상',
#  '타이틀곡',
#  '뮤직비디오',
#  '린지',
#  '교감',
#  '선생님',
#  '풀',
#  '펭수',
#  '갑자기',
#  '뱀',
#  '우리',
#  '펭수',
#  '눈물',
#  '펭귄',
#  '극장',
#  '펭귄',
#  '눈물',
#  '펭슈스',
#  '엄선',
#  '수학여행',
#  '옷',
#  '추천',
#  '펭수',
#  '소방관',
#  '펭수',
#  '무대',
#  '준비',
#  '연습생',
#  '옥상',
#  '뚝딱',
#  '선배',
#  '역대',
#  '깜짝',
#  '손님',
#  '펭수쇼',
#  '부',
#  '펭수',
#  '찰떡',
#  '장르',
#  '최초',
#  '공개',
#  '펭수쇼',
#  '부',
#  '당신',
#  '펭수',
#  '선택',
#  '직캠',
#  '힙합',
#  '펭수',
#  '기리보이',
#  '눈',
#  '매니저',
#  '투표',
#  '마감',
#  '선공',
#  '직캠',
#  '발라드',
#  '펭수',
#  '뚝딱',
#  '아이유',
#  '임슬옹',
#  '잔소리',
#  '투표',
#  '마감',
#  '선공',
#  '최초',
#  '연습생',
#  '펭수',
#  '오디션',
#  '합격',
#  '최초',
#  '공개',
#  '직캠',
#  '트로트',
#  '펭수',
#  '설운도',
#  '삼바',
#  '여인',
#  '투표',
#  '마감',
#  '선공',
#  '직캠',
#  '락',
#  '펭수',
#  '투표',
#  '마감',
#  '선공',
#  '연습생',
#  '펭수',
#  '남극',
#  '참치',
#  '정곡',
#  '요새',
#  '핫',
#  '그',
#  '참치',
#  '송',
#  '난',
#  '서울대',
#  '안',
#  '어른',
#  '반박',
#  '명절',
#  '잔소리',
#  '반대',
#  '시위',
#  '펭수',
#  '떡집',
#  '체험',
#  '나',
#  '소개',
#  '로비',
#  '컷팅식',
#  '펭수',
#  '독자',
#  '의리',
#  '테스트',
#  '매니저',
#  '흥',
#  '선배',
#  '뜬금',
#  '스피드',
#  '게임',
#  '펭수',
#  '복지',
#  '전격',
#  '공개',
#  '힐링',
#  '선물',
#  '종',
#  '세트',
#  '뜻',
#  '힐링',
#  '세상',
#  '담양',
#  '특산',
#  '물',
#  '담양',
#  '빗',
#  '재벌',
#  '펭귄',
#  '도서관',
#  '책',
#  '몽땅',
#  '일시',
#  '불로',
#  '본격',
#  '남',
#  '북',
#  '대결',
#  '너',
#  '북극곰',
#  '펭귄',
#  '누가',
#  '알',
#  '펭수',
#  '겨울왕국',
#  '커버',
#  '여름',
#  '펭귄',
#  '풀이',
#  '박',
#  '싱하',
#  '펭귄',
#  '처음',
#  '걸',
#  '감동',
#  '선물',
#  '언박싱',
#  '현장',
#  '경축',
#  '세계',
#  '최초',
#  '펭귄',
#  '팬싸',
#  '교보',
#  '꽉',
#  '광복절',
#  '의',
#  '펭귄',
#  '인간',
#  '역사',
#  '펭수',
#  '타',
#  '강사',
#  '낚시',
#  '편',
#  '펭수',
#  '매니저',
#  '비하인드',
#  '스토리',
#  '세상',
#  '공룡',
#  '우리',
#  '집',
#  '공룡',
#  '안물',
#  '겁',
#  '펭수',
#  '낚시',
#  '브이',
#  '로그',
#  '수능',
#  '살이',
#  '수능',
#  '문제',
#  '펭수',
#  '수능',
#  '모의고사',
#  '도전',
#  '펭수',
#  '분노',
#  '병뚜껑',
#  '린지',
#  '사연',
#  '슈퍼',
#  '콘',
#  '니',
#  '왜',
#  '내',
#  '머리',
#  '감겨',
#  '미용실',
#  '거대',
#  '펭귄',
#  '몰래카메라',
#  '자이언트',
#  '펭',
#  '납량',
#  '특집',
#  '펭귄',
#  '귀신',
#  '이야기',
#  '봄',
#  '지하',
#  '말',
#  '이유',
#  '펭수',
#  '자이언트',
#  '펭',
#  '자꾸',
#  '펭수',
#  '아이컨택',
#  '영상',
#  '피지',
#  '컬',
#  '갤러리',
#  '펭수',
#  '빡빡이',
#  '아저씨',
#  '키',
#  '운동',
#  '거',
#  '정말',
#  '피지',
#  '컬',
#  '갤러리',
#  '펭수',
#  '빡빡이',
#  '아저씨',
#  '특제',
#  '방학',
#  '용',
#  '헬린',
#  '운동',
#  '루틴',
#  '공개',
#  '피지',
#  '컬',
#  '갤러리',
#  '펭수',
#  '본격',
#  '헬린',
#  '양성',
#  '교육',
#  '방송',
#  '빡빡이',
#  '아저씨',
#  '거',
#  '누가',
#  '이말년',
#  '펭수',
#  '굿',
#  '만들기',
#  '펭수',
#  '토이스토리',
#  '이',
#  '세상',
#  '퀄',
#  '이말년',
#  '펭수',
#  '세상',
#  '굿',
#  '홈쇼핑',
#  '자꾸',
#  '교육방송',
#  '선',
#  '이말년',
#  '침착',
#  '맨',
#  '과',
#  '펭수',
#  '연습생',
#  '의',
#  '짤방',
#  '폭격',
#  '프로',
#  '듀스',
#  '펭수',
#  '당신',
#  '펭귄',
#  '투표',
#  '자기',
#  '소개',
#  '펭수',
#  '손흥민',
#  '슈퍼',
#  '콘',
#  '댄스',
#  '싱크로',
#  '도전',
#  '연기',
#  '마피아게임',
#  '더',
#  '펭수',
#  '고양예고',
#  '연기',
#  '마피아게임',
#  '인',
#  '게임',
#  '대회',
#  '계속',
#  '일등',
#  '미디어',
#  '중학생',
#  '인',
#  '전지영',
#  '김다윤',
#  '산초',
#  '펭수',
#  '근원',
#  '인',
#  '게임',
#  '대회',
#  '펭수',
#  '게임',
#  '펭수쇼',
#  '고양예고',
#  '선배',
#  '직접',
#  '예고',
#  '라이프',
#  '모든',
#  '것',
#  '예술',
#  '학생',
#  '아크로바틱',
#  '발레',
#  '고양예고',
#  '예술',
#  '천재',
#  '펭수',
#  '고양예고',
#  '테스트',
#  '도전',
#  '음악',
#  '미술',
#  '뿌셔',
#  '진짜',
#  '성우',
#  '복만',
#  '마법소녀물',
#  '더빙',
#  '대결',
#  '플라워',
#  '링',
#  '하트',
#  '펭수',
#  '복만',
#  '피',
#  '땀',
#  '눈물',
#  '성우',
#  '수업',
#  '현장',
#  '엽떡',
#  '닭발',
#  '연애',
#  '친구',
#  '관계',
#  '펭수',
#  '세상',
#  '고민',
#  '부숴',
#  '펭수',
#  '죽',
#  '고민',
#  '담소',
#  '논란',
#  '종결',
#  '매니저',
#  '과연',
#  '머',
#  '머리',
#  '것',
#  '이말년',
#  '핸드',
#  '메이드',
#  '펭수',
#  '굿',
#  '판매',
#  '라이브',
#  '침착',
#  '맨',
#  '펭',
#  '그녀',
#  '펭수',
#  '걸그룹',
#  '도전',
#  '기',
#  '펭수',
#  '걸그룹',
#  '데뷔',
#  '실제',
#  '오디션',
#  '현장',
#  '공개',
#  '것',
#  '바로',
#  '아이돌',
#  '연습생',
#  '실체',
#  '유명',
#  '기획사',
#  '연습생',
#  '은밀',
#  '이야기',
#  '찍',
#  '때',
#  '왜',
#  '눈',
#  '졸업사진',
#  '공감',
#  '유형',
#  '김다윤',
#  '슨배림',
#  '삭발',
#  '국토',
#  '대장정',
#  '독자',
#  '만',
#  '명',
#  '내기',
#  '카운트다운',
#  '펭수',
#  '어벤져스',
#  '무기',
#  '종',
#  '세트',
#  '단돈',
#  '천원',
#  '다이소',
#  '세계',
#  '최초',
#  '펭귄',
#  '펭수',
#  '만',
#  '명',
#  '돌파',
#  '기념',
#  '펭수',
#  '은밀',
#  '털',
#  '소리',
#  '공개',
#  '펭수',
#  '위해',
#  '히어로즈',
#  '자이언트',
#  '펭',
#  '티저',
#  '슈스',
#  '펭수',
#  '광고',
#  '데뷔',
#  '자이언트',
#  '펭',
#  '티저',
#  '펭수',
#  '눈물',
#  '첫',
#  '라이브',
#  '방송',
#  '편집',
#  '버전',
#  '갑',
#  '분',
#  '연',
#  '연',
#  '연예인',
#  '펭수',
#  '힐링',
#  '한강',
#  '휴가',
#  '펭수',
#  '댓글',
#  '두',
#  '이야기',
#  '근원',
#  '펭수',
#  '한강',
#  '수영',
#  '라이브',
#  '살',
#  '펭수',
#  '남극',
#  '펭수',
#  '해외',
#  '진출',
#  '준비',
#  '펭수',
#  '귀염',
#  '외국어',
#  '송',
#  '이벤트',
#  '보기',
#  '배꼽',
#  '잡고',
#  '선물',
#  '민속촌',
#  '숨',
#  '백법',
#  '펭수',
#  '사람',
#  '소름',
#  '주의',
#  '초딩',
#  '민속촌',
#  '펭수',
#  '멘붕',
#  '온',
#  '오늘',
#  '펭수',
#  '매니저',
#  '일',
#  '시',
#  '요',
#  '펭수',
#  '매니저',
#  '뜻밖',
#  '팬미팅',
#  '금손',
#  '성덕',
#  '파티',
#  '제',
#  '펭수',
#  '표현',
#  '대회',
#  '홍대',
#  '댄스배틀',
#  '펭귄',
#  '펭수',
#  '스트릿',
#  '댄서',
#  '쿠마',
#  '연습생',
#  '라면',
#  '버스킹',
#  '거대',
#  '펭귄',
#  '홍대',
#  '습격',
#  '사건',
#  '지하',
#  '소품',
#  '실',
#  '펭귄',
#  '산다',
#  '펭수',
#  '은밀',
#  '사생활',
#  '공',
#  '개',
#  '펭수',
#  '오열',
#  '파티',
#  '펭수',
#  '뽀로로',
#  '최종',
#  '뽀로로',
#  '펭귄',
#  '펭귄',
#  '전문가',
#  '등장',
#  '오랬더',
#  '진짜',
#  '펭수',
#  '뽀로로',
#  '배틀',
#  '스타트',
#  '우주',
#  '전쟁',
#  '서막',
#  '펭수',
#  '중대',
#  '발표',
#  '초',
#  '특급',
#  '게스트',
#  '펭수',
#  '독자',
#  '돌파',
#  '기념',
#  '댓글',
#  '시민',
#  '벚꽃놀이',
#  '인생',
#  '샷',
#  '방출',
#  '자이언트',
#  '펭',
#  '벚꽃',
#  '초면',
#  '관종',
#  '펭귄',
#  '인생',
#  '샷',
#  '펭수',
#  '남매',
#  '두',
#  '피',
#  '눈물',
#  '펭수',
#  '에이미',
#  '리다',
#  '공개',
#  '비책',
#  '펭수',
#  '남매',
#  '첫',
#  '크리에이터',
#  '대결',
#  '거대',
#  '펭귄',
#  '눈물',
#  '샌드위치',
#  '먹방',
#  '펭수',
#  '남매',
#  '어디',
#  '선',
#  '구독',
#  '자의',
#  '냄새',
#  '펭수',
#  '두',
#  '스승',
#  '남매',
#  '전지영',
#  '스승',
#  '펭수',
#  '인',
#  '더',
#  '특단',
#  '조치',
#  '관종',
#  '펭귄',
#  '스타',
#  '전지영',
#  '매니저',
#  '직캠',
#  '거대',
#  '펭귄',
#  '소름',
#  '요들송',
#  '라이브',
#  '전학생',
#  '교장',
#  '선생님',
#  '펭수',
#  '교장',
#  '실',
#  '급습',
#  '관종',
#  '펭귄',
#  '초등학교',
#  '습격',
#  '펭수',
#  '학교',
#  '관종',
#  '펭귄',
#  '펭수',
#  '데뷔',
#  '자이언트',
#  '펭',
#  '연습생',
#  '펭귄',
#  '방송국',
#  '점거',
#  '자이언트',
#  '펭',
#  '펭',
#  '연습생',
#  '펭수',
#  '유튜브',
#  '데뷔',
#  '머랭',
#  '쿠키',
#  '먹방',
#  '역대',
#  '카',
#  '오스',
#  '카메라',
#  '차단',
#  '강제',
#  '탐사보도',
#  '타이어',
#  '매장',
#  '알바',
#  '리뷰',
#  '민속촌',
#  '패밀리',
#  '워크맨',
#  '키즈',
#  '카페',
#  '그냥',
#  '커피',
#  '라면',
#  '어린이집',
#  '동심',
#  '눈물',
#  '폭발',
#  '체력',
#  '멘탈',
#  '폭발',
#  '오디오',
#  '감독',
#  '고막',
#  '폭발',
#  '어린이집',
#  '교사',
#  '리뷰',
#  '워크맨',
#  '하루',
#  '람보르기니',
#  '외제차',
#  '한류',
#  '스타',
#  '더블',
#  '영접',
#  '청담동',
#  '주유소',
#  '알바',
#  '리뷰',
#  '워크맨',
#  '길',
#  '치가',
#  '배달',
#  '알바',
#  '일',
#  '비',
#  '경로',
#  '이탈',
#  '시간',
#  '초과',
#  '치킨',
#  '간',
#  '체적',
#  '난국',
#  '배달',
#  '알바',
#  '리뷰',
#  '워크맨',
#  '영상',
#  '냄새',
#  '남',
#  '워크맨',
#  '최초',
#  '시급',
#  '업무',
#  '사장',
#  '낭만',
#  '뿜뿜',
#  '놀멍쉬멍',
#  '제주도',
#  '게스트하우스',
#  '스탭',
#  '리뷰',
#  '워크맨',
#  '잠시',
#  '포상',
#  '휴가',
#  '줄',
#  '알',
#  '세상',
#  '서비스',
#  '온',
#  '급',
#  '호텔리어',
#  '리뷰',
#  '워크맨',
#  '이정재',
#  '정웅인',
#  '대한민국',
#  '명',
#  '배우',
#  '집합',
#  '드라마',
#  '장성규',
#  '보조',
#  '출연',
#  '알바',
#  '리뷰',
#  '워크맨',
#  '궁서체',
#  '것',
#  '위해',
#  '이번',
#  '워크맨',
#  '사람인',
#  '혈압',
#  '주의',
#  '옷가게',
#  '알바',
#  '최악',
#  '변태',
#  '진상',
#  '손놈',
#  '만난',
#  '상상',
#  '초월',
#  '의류',
#  '매장',
#  '알바',
#  '리뷰',
#  '워크맨',
#  '돌파',
#  '축하',
#  '게',
#  '드립',
#  '생선',
#  '드립',
#  '봄',
#  '해산물',
#  '제철',
#  '기념',
#  '날로',
#  '수산시장',
#  '알바',
#  '리뷰',
#  '워크맨',
#  '민속촌',
#  '아마존',
#  '구역',
#  '안',
#  '세상',
#  '드립',
#  '폭발',
#  '민속촌',
#  '알바',
#  '리뷰',
#  '워크맨',
#  '안전',
#  '제일',
#  '것',
#  '제일',
#  '장성규',
#  '고생',
#  '길',
#  '일',
#  '줌',
#  '쌀',
#  '아파트',
#  '건설',
#  '현장',
#  ...]

# %%
# 제목, 본문 내용, 댓글 내용 하나의 리스트로 취합
title_f = flatten(title_list)
content_f = flatten(content_list)
reply_f = flatten(reply_list)

# %%
# 단어 빈도수 확인을 위한 패키지 import
from nltk.book import *
import operator
from nltk.corpus import brown
from nltk.corpus import stopwords
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# 제목 빈도수 확인
fdist1 = FreqDist(title_f)
title_dict = {}
content_dict = {}
reply_dict = {}

dict_w = {}
for w in title_f:
    dict_w[w] = fdist1[w]
title_dict = sorted(dict_w.items(), key=operator.itemgetter(1), reverse=True)
print(title_dict)
# Out:
# [('펭수', 87), ('워크맨', 38), ('펭귄', 30), ('리뷰', 29), ('알바', 28), ('펭', 13), ('채널', 12), ('공개', 11), ('독립', 10), ('매니저', 9), ('연습생', 9), ('세상', 8), ('자이언트', 8), ('장성규', 8), ('라이브', 7), ('독자', 7), ('눈물', 7), ('역대', 7), ('최초', 7), ('선배', 5), ('직캠', 5), ('투표', 5), ('게임', 5), ('인', 5), ('것', 5), ('데뷔', 5), ('민속촌', 5), ('언박싱', 4), ('대결', 4), ('편', 4), ('방송', 4), ('마감', 4), ('선공', 4), ('현장', 4), ('도전', 4), ('거대', 4), ('이말년', 4), ('고양예고', 4), ('기념', 4), ('관종', 4), ('남매', 4), ('폭발', 4), ('세계', 3), ('린지', 3), ('영상', 3), ('남극', 3), ('등장', 3), ('우리', 3), ('남', 3), ('첫', 3), ('학교', 3), ('극장', 3), ('스타', 3), ('진짜', 3), ('펭수쇼', 3), ('안', 3), ('힐링', 3), ('선물', 3), ('본격', 3), ('알', 3), ('의', 3), ('수능', 3), ('이야기', 3), ('말', 3), ('피지', 3), ('컬', 3), ('갤러리', 3), ('빡빡이', 3), ('아저씨', 3), ('굿', 3), ('선', 3), ('대회', 3), ('전지영', 3), ('은밀', 3), ('명', 3), ('돌파', 3), ('댓글', 3), ('두', 3), ('주의', 3), ('일', 3), ('홍대', 3), ('뽀로로', 3), ('인생', 3), ('먹방', 3), ('배달', 3), ('시급', 3), ('사장', 3), ('드립', 3), ('끝판', 3), ('꿀', 3), ('극한', 3), ('게', 2), ('팬', 2), ('신상', 2), ('이', 2), ('스', 2), ('인간', 2), ('버튼', 2), ('처음', 2), ('나', 2), ('공', 2), ('비화', 2), ('개', 2), ('정복기', 2), ('추억', 2), ('친구', 2), ('한류', 2), ('축하', 2), ('전격', 2), ('나이', 2), ('살', 2), ('내', 2), ('시간', 2), ('선생님', 2), ('준비', 2), ('뚝딱', 2), ('부', 2), ('당신', 2), ('눈', 2), ('잔소리', 2), ('오디션', 2), ('참치', 2), ('송', 2), ('소개', 2), ('테스트', 2), ('복지', 2), ('종', 2), ('세트', 2), ('담양', 2), ('누가', 2), ('낚시', 2), ('공룡', 2), ('집', 2), ('사연', 2), ('슈퍼', 2), ('콘', 2), ('왜', 2), ('머리', 2), ('미용실', 2), ('특집', 2), ('봄', 2), ('지하', 2), ('자꾸', 2), ('운동', 2), ('거', 2), ('방학', 2), ('헬린', 2), ('양성', 2), ('침착', 2), ('맨', 2), ('연기', 2), ('마피아게임', 2), ('더', 2), ('김다윤', 2), ('근원', 2), ('예고', 2), ('예술', 2), ('음악', 2), ('성우', 2), ('복만', 2), ('피', 2), ('고민', 2), ('걸그룹', 2), ('기', 2), ('아이돌', 2), ('찍', 2), ('만', 2), ('어벤져스', 2), ('위해', 2), ('티저', 2), ('연', 2), ('한강', 2), ('휴가', 2), ('소름', 2), ('온', 2), ('파티', 2), ('제', 2), ('라면', 2), ('습격', 2), ('실', 2), ('최종', 2), ('샷', 2), ('냄새', 2), ('스승', 2), ('교장', 2), ('카', 2), ('차단', 2), ('매장', 2), ('키즈', 2), ('카페', 2), ('어린이집', 2), ('오디오', 2), ('길', 2), ('치킨', 2), ('줄', 2), ('아마존', 2), ('제일', 2), ('의외', 2), ('류', 2), ('환', 2), ('각', 2), ('덕후', 2), ('에버랜드', 2), ('파업', 2), ('선언', 2), ('돈', 2), ('회사', 2), ('직업', 2), ('피자', 2), ('수', 2), ('충격', 2), ('맥주', 2), ('소개팅', 2), ('꿀팁', 2), ('스포', 2), ('만렙', 2), ('전', 1), ('외교부', 1), ('화보', 1), ('모델', 1), ('최강', 1), ('컬래버레이션', 1), ('뮤비', 1), ('수험생', 1), ('지금', 1), ('당장', 1), ('정승', 1), ('쌤', 1), ('유치원', 1), ('동창회', 1), ('시작', 1), ('둘리', 1), ('윤도현', 1), ('본부', 1), ('만남', 1), ('호흡', 1), ('난리', 1), ('사관학교', 1), ('데이트', 1), ('실버', 1), ('날개', 1), ('잠입', 1), ('행운', 1), ('카드', 1), ('탄생', 1), ('퇴사', 1), ('이제야', 1), ('진행', 1), ('관심사', 1), ('간다', 1), ('비밀', 1), ('외로워', 1), ('해외진출', 1), ('프랑스', 1), ('트렌치코트', 1), ('단독', 1), ('의혹', 1), ('해부', 1), ('독점', 1), ('인터뷰', 1), ('김민교', 1), ('양치', 1), ('승', 1), ('변경', 1), ('안내', 1), ('야유회', 1), ('지옥', 1), ('타이틀곡', 1), ('뮤직비디오', 1), ('교감', 1), ('풀', 1), ('갑자기', 1), ('뱀', 1), ('펭슈스', 1), ('엄선', 1), ('수학여행', 1), ('옷', 1), ('추천', 1), ('소방관', 1), ('무대', 1), ('옥상', 1), ('깜짝', 1), ('손님', 1), ('찰떡', 1), ('장르', 1), ('선택', 1), ('힙합', 1), ('기리보이', 1), ('발라드', 1), ('아이유', 1), ('임슬옹', 1), ('합격', 1), ('트로트', 1), ('설운도', 1), ('삼바', 1), ('여인', 1), ('락', 1), ('정곡', 1), ('요새', 1), ('핫', 1), ('그', 1), ('난', 1), ('서울대', 1), ('어른', 1), ('반박', 1), ('명절', 1), ('반대', 1), ('시위', 1), ('떡집', 1), ('체험', 1), ('로비', 1), ('컷팅식', 1), ('의리', 1), ('흥', 1), ('뜬금', 1), ('스피드', 1), ('뜻', 1), ('특산', 1), ('물', 1), ('빗', 1), ('재벌', 1), ('도서관', 1), ('책', 1), ('몽땅', 1), ('일시', 1), ('불로', 1), ('북', 1), ('너', 1), ('북극곰', 1), ('겨울왕국', 1), ('커버', 1), ('여름', 1), ('풀이', 1), ('박', 1), ('싱하', 1), ('걸', 1), ('감동', 1), ('경축', 1), ('팬싸', 1), ('교보', 1), ('꽉', 1), ('광복절', 1), ('역사', 1), ('타', 1), ('강사', 1), ('비하인드', 1), ('스토리', 1), ('안물', 1), ('겁', 1), ('브이', 1), ('로그', 1), ('살이', 1), ('문제', 1), ('모의고사', 1), ('분노', 1), ('병뚜껑', 1), ('니', 1), ('감겨', 1), ('몰래카메라', 1), ('납량', 1), ('귀신', 1) ...

# %%
# 본문 내용 빈도수 확인
fdist1 = FreqDist(content_f)
dict_w = {}
for w in content_f:
    dict_w[w] = fdist1[w]
content_dict = sorted(dict_w.items(), key=operator.itemgetter(1), reverse=True)
print(content_dict)
# Out:
# [('펭수', 130), ('리뷰', 74), ('알바', 69), ('장성규', 60), ('워크맨', 47), ('직업', 37), ('스튜디오', 34), ('펭', 28), ('펭귄', 25), ('인력', 23), ('것', 20), ('영상', 19), ('독자', 18), ('자이언트', 18), ('매니저', 16), ('소장', 16), ('잡것', 16), ('공개', 14), ('수', 14), ('친구', 13), ('여러분', 12), ('연습생', 12), ('나', 11), ('우리', 11), ('위해', 10), ('선배', 10), ('덜', 10), ('위', 9), ('이번', 9), ('이', 9), ('남극', 9), ('더', 9), ('편', 9), ('세상', 7), ('거', 7), ('꿀팁', 7), ('앞', 7), ('크리에이터', 7), ('뽀로로', 7), ('시간', 6), ('하나', 6), ('방', 6), ('게', 6), ('내', 6), ('준비', 6), ('말', 6), ('지금', 6), ('눈', 6), ('게임', 6), ('사람', 6), ('방송', 6), ('팬', 6), ('체험', 6), ('스승', 6), ('채널', 6), ('에버랜드', 6), ('눈물', 5), ('펭펭', 5), ('워', 5), ('오', 5), ('과연', 5), ('이유', 5), ('시작', 5), ('풀', 5), ('인', 5), ('알', 5), ('라이브', 5), ('도전', 5), ('만', 5), ('명', 5), ('안', 5), ('첫', 5), ('배달', 5), ('데뷔', 5), ('실화', 5), ('남매', 5), ('알바생', 5), ('술집', 5), ('촬영', 4), ('직접', 4), ('힙합', 4), ('린지', 4), ('참여', 4), ('날', 4), ('갑자기', 4), ('진', 4), ('가지', 4), ('기', 4), ('셀럽', 4), ('한국', 4), ('제일', 4), ('안전', 4), ('대결', 4), ('시민', 4), ('잔소리', 4), ('수가', 4), ('콜라보', 4), ('오늘', 4), ('성우', 4), ('고민', 4), ('달성', 4), ('한강', 4), ('꿀', 4), ('댓글', 4), ('민속촌', 4), ('버스킹', 4), ('주의', 4), ('제주도', 4), ('일', 4), ('소', 4), ('화보', 3), ('모델', 3), ('디', 3), ('보고', 3), ('확인', 3), ('의', 3), ('진출', 3), ('방출', 3), ('주재', 3), ('사랑', 3), ('건', 3), ('구독', 3), ('난', 3), ('패션', 3), ('특별', 3), ('일일', 3), ('펭수쇼', 3), ('공연', 3), ('발라드', 3), ('락', 3), ('분', 3), ('투표', 3), ('직캠', 3), ('원', 3), ('공포', 3), ('특집', 3), ('펭하', 3), ('미디어', 3), ('때문', 3), ('두', 3), ('여름', 3), ('끝', 3), ('미용실', 3), ('사실', 3), ('홈', 3), ('맨', 3), ('이말년', 3), ('손흥민', 3), ('고양예고', 3), ('예술', 3), ('주목', 3), ('덕분', 3), ('아이돌', 3), ('현장', 3), ('홍보', 3), ('광', 3), ('슨배릠', 3), ('동년배', 3), ('소통', 3), ('인생', 3), ('유튜브', 3), ('보기', 3), ('진짜', 3), ('보이', 3), ('계속', 3), ('전지영', 3), ('선생님', 3), ('때', 3), ('어린이집', 3), ('항상', 3), ('요즘', 3), ('울', 3), ('술', 3), ('편의점', 3), ('무엇', 3), ('등장', 3), ('도미노피자', 3), ('독립', 3), ('맥주', 3), ('뜻밖', 3), ('영화관', 3), ('워터파크', 3), ('해외진출', 2), ('노력', 2), ('수의', 2), ('커버', 2), ('드', 2), ('월미도', 2), ('뮤비', 2), ('모두', 2), ('긴급', 2), ('옆', 2), ('꿈', 2), ('내일', 2), ('시험', 2), ('동창회', 2), ('잡', 2), ('통해', 2), ('자랑', 2), ('입', 2), ('질', 2), ('간다', 2), ('화', 2), ('꿀잼', 2), ('본부', 2), ('정체', 2), ('일요일', 2), ('밤', 2), ('프랑스', 2), ('영광', 2), ('당근', 2), ('살', 2), ('용', 2), ('본방', 2), ('톡', 2), ('보니하니', 2), ('자주', 2), ('공원', 2), ('온', 2), ('못', 2), ('미안', 2), ('처음', 2), ('혼자', 2), ('남', 2), ('다른', 2), ('노', 2), ('스타', 2), ('너', 2), ('초등학교', 2), ('혁신', 2), ('수학여행', 2), ('게스트', 2), ('큐', 2), ('뚝딱', 2), ('트로트', 2), ('오디션', 2), ('참고', 2), ('버전', 2), ('유', 2), ('참치', 2), ('그냥', 2), ('등', 2), ('벌금', 2), ('페스티벌', 2), ('케어', 2), ('부분', 2), ('젤', 2), ('대표', 2), ('카트', 2), ('종', 2), ('초월', 2), ('조금', 2), ('수능', 2), ('독점', 2), ('슈퍼', 2), ('콘', 2), ('결과', 2), ('뭐', 2), ('보장', 2), ('마', 2), ('날씨', 2), ('당신', 2), ('멘탈', 2), ('소원', 2), ('세', 2), ('운동', 2), ('곳', 2), ('향', 2), ('아저씨', 2), ('죽', 2), ('세계', 2), ('최초', 2), ('굿', 2), ('호강', 2), ('무려', 2), ('기타리스트', 2), ('찰떡', 2), ('소리', 2), ('삭발', 2), ('덕후', 2), ('야구', 2), ('대회', 2), ('너희', 2), ('핫', 2), ('이야기', 2), ('펭성', 2), ('음악', 2), ('제', 2), ('구', 2), ('유명', 2), ('후보', 2), ('누구', 2), ('걸그룹', 2), ('차', 2), ('애', 2), ('공감', 2), ('히어로', 2), ('머랭', 2), ('쿠키', 2), ('은밀', 2), ('려', 2), ('줄', 2), ('주기', 2), ('문제', 2), ('연예인', 2), ('발견', 2), ('기념', 2), ('헤엄', 2), ('사수', 2), ('습격', 2), ('초딩', 2), ('금손', 2), ('홍대', 2), ('실', 2), ('편집', 2), ('오열', 2), ('와중', 2), ('신청', 2), ('전하', 2), ('샷', 2), ('피', 2), ('브', 2), ('인기', 2), ('임', 2), ('교장', 2), ('회사', 2), ('타이어', 2), ('무', 2), ('주유소', 2), ('호텔리어', 2), ('옷', 2), ('드립', 2), ('취뽀', 2), ('취업', 2), ('고갈', 2), ('우조', 2), ('오장', 2), ('해양수산부', 2), ('건설', 2), ('노래방', 2), ('방송국', 2), ('돌이', 2), ('항공사', 2), ('역대', 2), ('버튼', 2), ('정도', 2), ('기대', 2), ('텐션', 2), ('메가박스', 2), ('만렙', 2), ('뒤', 2), ('끝판', 2), ('반도', 2), ('시급', 2), ('공짜', 2), ('치킨', 2), ('키즈', 2), ('카페', 2), ('고깃집', 2), ('단기', 2), ('전단지', 2), ('로서', ...

# %%
# 댓글 내용 빈도수 확인
fdist1 = FreqDist(reply_f)
dict_w = {}
for w in reply_f:
    dict_w[w] = fdist1[w]
reply_dict = sorted(dict_w.items(), key=operator.itemgetter(1), reverse=True)
print(reply_dict)
# Out:
# [('펭수', 1659), ('진짜', 360), ('거', 236), ('때', 227), ('것', 212), ('펭', 207), ('이', 207), ('우리', 203), ('사람', 189), ('나', 182), ('왜', 172), ('내', 158), ('영상', 155), ('너', 151), ('펭귄', 142), ('워크맨', 142), ('말', 139), ('저', 119), ('목소리', 119), ('더', 115), ('생각', 109), ('매니저', 107), ('그', 105), ('보고', 104), ('댓글', 96), ('수', 91), ('살', 86), ('친구', 86), ('장성규', 86), ('좀', 85), ('안', 84), ('뭐', 83), ('어른', 80), ('개', 80), ('어린이', 80), ('애', 78), ('일', 78), ('알바', 77), ('분', 73), ('지금', 73), ('정말', 73), ('사랑', 71), ('알', 70), ('사장', 69), ('모든', 64), ('난', 61), ('하나', 60), ('게', 59), ('때문', 58), ('또', 57), ('걸', 55), ('이제', 55), ('굿', 54), ('애기', 54), ('노래', 54), ('제', 53), ('마음', 53), ('아이', 52), ('세상', 52), ('김명중', 52), ('편집', 51), ('진', 51), ('시간', 51), ('소리', 51), ('여기', 49), ('인력', 49), ('방송', 48), ('뽀로로', 48), ('중', 47), ('그냥', 47), ('해', 46), ('전', 46), ('한번', 46), ('제일', 45), ('못', 44), ('편', 44), ('리뷰', 44), ('팬', 43), ('직원', 43), ('남극', 43), ('선생님', 43), ('앞', 42), ('요즘', 42), ('독자', 42), ('이번', 41), ('줄', 41), ('웃기', 40), ('오늘', 39), ('펭펭', 39), ('채널', 39), ('회사', 38), ('처음', 38), ('살이', 38), ('뚝딱', 38), ('나이', 38), ('니', 37), ('번', 37), ('임', 37), ('유튜브', 37), ('돈', 37), ('표정', 37), ('구독', 36), ('계속', 36), ('꼭', 36), ('다시', 36), ('느낌', 36), ('제발', 36), ('이름', 36), ('목', 35), ('선배', 35), ('자이언트', 35), ('배', 34), ('보', 34), ('듯', 33), ('날', 33), ('역시', 33), ('뒤', 33), ('장난', 33), ('탈', 32), ('위', 32), ('마지막', 32), ('눈물', 32), ('드립', 32), ('맨', 32), ('고생', 31), ('시작', 31), ('건', 31), ('위해', 31), ('정도', 31), ('동년배', 31), ('명', 31), ('팽수', 31), ('제작', 30), ('항상', 30), ('얼굴', 30), ('다른', 30), ('곳', 30), ('누가', 30), ('이비에스', 30), ('추천', 30), ('청소', 30), ('자막', 29), ('한국', 29), ('자꾸', 29), ('최고', 29), ('눈', 29), ('무슨', 28), ('인기', 28), ('위로', 28), ('촬영', 28), ('피디', 28), ('정', 28), ('도', 28), ('인형', 28), ('함', 28), ('아나운서', 28), ('직접', 28), ('엄마', 27), ('연락', 27), ('누구', 27), ('진심', 27), ('온', 26), ('여러분', 26), ('버튼', 26), ('얘기', 26), ('머리', 26), ('외', 26), ('부분', 26), ('건강', 26), ('왤케', 26), ('인', 26), ('요', 26), ('옷', 26), ('직업', 26), ('성규', 26), ('방송국', 25), ('모습', 25), ('출연', 25), ('네', 25), ('움', 25), ('볼', 25), ('손', 25), ('배달', 25), ('웃음', 24), ('하루', 24), ('놈', 24), ('사실', 24), ('티비', 24), ('참치', 24), ('요들송', 24), ('학교', 24), ('완전', 24), ('바로', 24), ('데', 24), ('이유', 24), ('가능', 24), ('부문', 24), ('감동', 23), ('맘', 23), ('뭔가', 23), ('컨텐츠', 23), ('팀', 23), ('화이팅', 23), ('땐', 23), ('얼마나', 23), ('자기', 23), ('고', 23), ('근원', 23), ('상', 23), ('소', 23), ('교육방송', 22), ('모두', 22), ('인생', 22), ('로', 22), ('식당', 22), ('몸', 22), ('울', 22), ('물류', 22), ('를', 21), ('춤', 21), ('매일', 21), ('박재영', 21), ('언제', 21), ('교육', 21), ('요리', 21), ('공장', 21), ('잡것', 21), ('먹기', 21), ('속', 20), ('영', 20), ('체험', 20), ('주행', 20), ('퇴사', 20), ('후', 20), ('의', 20), ('혼자', 20), ('다음', 20), ('이건', 20), ('가장', 20), ('철거', 20), ('사절', 20), ('예능', 19), ('아기', 19), ('연습생', 19), ('달라', 19), ('수가', 19), ('캐릭터', 19), ('박', 19), ('관리', 19), ('응원', 19), ('이해', 19), ('반', 19), ('출연자', 19), ('용', 19), ('집', 19), ('말투', 18), ('저희', 18), ('힘', 18), ('보기', 18), ('이모티콘', 18), ('수능', 18), ('매력', 18), ('오', 18), ('척', 18), ('아저씨', 18), ('선', 18), ('사진', 18), ('대체', 18), ('펭하', 17), ('갑자기', 17), ('스타', 17), ('프로', 17), ('층', 17), ('인터뷰', 17), ('덕분', 17), ('물', 17), ('성우', 17), ('앜', 17), ('밥', 17), ('보조', 17), ('사회', 16), ('개인', 16), ('덕질', 16), ('축하', 16), ('워', 16), ('펭수님', 16), ('혹시', 16), ('아빠', 16), ('넼', 16), ('이모', 16), ('자주', 16), ('컨셉', 16), ('무엇', 16), ('여름', 16), ('왜케', 16), ('광고', 16), ('입', 16), ('분위기', 16), ('선물', 16), ('대박', 16), ('기네', 16), ('이야기', 15), ('넌', 15), ('이상', 15), ('홍보', 15), ('문제', 15), ('교사', 15), ('거의', 15), ('형', 15), ('여자', 15), ('그거', 15), ('카드', 15), ('어디', 15), ('초등학생', 15), ('발', 15), ('손님', 15), ('힐링', 14), ('걱정', 14), ('구', 14), ('인사', 14), ('아들', 14), ('동안', 14), ('아무', 14), ('운동', 14), ('끝', 14), ('중간', 14), ('안녕', 14), ('재', 14), ('널', 14), ('센스', 14), ('등', 14), ('해도', 14), ('차', 14), ('표현', 14), ('모자', 14), ('슈퍼', 14), ('폴리스', 14), ...

# %%
# 빈도수를 데이터프레임 형태로 저장
title_df = DataFrame(title_dict)
content_df = DataFrame(content_dict)
reply_df = DataFrame(reply_dict)

# %%
title_df.head() # 데이터 확인
# Out:
#      0   1
# 0   펭수  87
# 1  워크맨  38
# 2   펭귄  30
# 3   리뷰  29
# 4   알바  28

# %%
####### Machine Learning #################
paw_reply.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-33f4e7fe4581> in <module>
#       1 #######################################
#       2 ### NMF
# ----> 3 content_df.head()
#
# NameError: name 'content_df' is not defined

# %%
paw_reply.drop('Comment', axis=1, inplace=True)
paw_reply.drop('Like', axis=1, inplace=True)
paw_reply.drop('Title_number', axis=1, inplace=True)

# %%
paw_reply.head()

# %%
X_train = paw_reply.drop("구분", axis=1)  # 예측값
Y_train = paw_reply.drop("구분", axis=1)  # 실제값

X_test = paw_reply.drop("구분" , axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((3160, 5), (3160, 5), (3160, 5))

# %%
# 1. Logistic Regression
logreg = LogisticRegression(solver='lbfgs')
logreg.fit(X_train, Y_train)

type(X_train)
type(Y_train)

Y_pred = logreg.predict(X_test)
acc_log=logreg.score(X_train, Y_train)
acc_log

# %%
# 2. Support Vector Machines
svc = SVC()
solver='liblinear'
svc.fit(X_train, Y_train)

Y_pred = svc.predict(X_test)
acc_svc = svc.score(X_train, Y_train)
print(acc_svc)

# %%
# 3. Decision Tree
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, Y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
acc_decision_tree

# %%
# 4. KNN
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn

# %%
# 5. Gaussian Naive Bayes
gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
Y_pred = gaussian.predict(X_test)
acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
acc_gaussian

# %%
# 6. Linear SVC
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)
Y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
acc_linear_svc

# %%
# 7. Perceptron
perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
Y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
acc_perceptron

# %%
# 8. Random Forest
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, Y_train)
acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
acc_random_forest

# %%
# 9. Stochastic Gradient Descent

sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
acc_sgd
