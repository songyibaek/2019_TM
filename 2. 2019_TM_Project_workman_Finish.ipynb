# %%
# 패키지 import
import datetime as dt
import pandas as pd
import requests
import time
import urllib.request 
import re     
import konlpy

from bs4 import BeautifulSoup
from pandas import DataFrame
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

# %%
#크롬 드라이버 연결
delay=0.1
browser = Chrome()
browser.implicitly_wait(delay)

start_url  = 'https://www.youtube.com/channel/UCwx6n_4OcLgzAGdty0RWCoA/videos'
browser.get(start_url)  
browser.maximize_window()

body = browser.find_element_by_tag_name('body')#스크롤하기 위해 소스 추출
num_of_pagedowns = 30

#스크롤 다운
while num_of_pagedowns:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)
    num_of_pagedowns -= 1

# %%
# 페이지 소스 받아오기
html0 = browser.page_source
html = BeautifulSoup(html0,'html.parser')

# %%
# 리스트 선언
title_list = [] #제목 리스트 생성
href_list = [] #주소 리스트 생성
viewcountmake_list = [] #조회수 크롤링 위한 리스트 생성
viewcount_list = [] #조회수 리스트 생성

# %%
# 구독자 수 저장
subsc = html.find(id="subscriber-count").text
subsc = subsc[4:]

# title 저장
for tr in html.find_all(id="video-title"):
    title = tr.get('title')
    title_list.append(title)

#href 태그 내용 저장
for tr in html.find_all(id="video-title"):
    href = tr.get('href')
    href_list.append(href)
    
# 조회수 저장
for tr in html.find_all('span', class_="style-scope ytd-grid-video-renderer"):
    viewcount = tr.get_text('span')
    viewcountmake_list.append(viewcount)
    
contents_count = len(title_list)

#구독자수, 동영상 수
print("구독자 수:",subsc, ",영상 개수:", contents_count)
# Out:
# 구독자 수: 354만명 ,영상 개수: 35

# %%
intro_df = pd.DataFrame({'구분': "워크맨", '구독자':subsc, '영상수':contents_count}, index = [2])
intro_df.head()
# Out:
#     구분    구독자  영상수
# 2  워크맨  354만명   35

# %%
#전처리 전 title, 주소, 좋아요수 데이터프레임 생성
print(len(title_list), len(href_list), len(viewcountmake_list))
# viewcountmake_list의 경우 조회수와 등록일이 각각 생성되어 list크기가 다름 -> 데이터프레임 생성 불가
# Out:
# 35 35 70

# %%
# 데이터 클리닝 작업(조회수와 등록일에서 등록일 제거)
for tr in range(0,len(viewcountmake_list),2):
    a = viewcountmake_list[tr]
    viewcount_list.append(a)
    
# 조회수 데이터 전처리
clean_viewcount = []
for i in viewcount_list:
    a = i[4:-2]
    amul = float(a)*10000
    clean_viewcount.append(int(amul))
print(clean_viewcount)
# Out:
# [3500000, 4870000, 5980000, 2310000, 5500000, 6510000, 6110000, 5130000, 7060000, 6670000, 7280000, 7030000, 2650000, 7600000, 6790000, 8800000, 7970000, 8330000, 10800000, 13900000, 9600000, 7340000, 1930000, 6310000, 8590000, 3490000, 5210000, 4940000, 6440000, 2860000, 5180000, 4450000, 4310000, 3600000, 4420000]

# %%
#title, 주소, 좋아요수 데이터프레임 생성
work_list = pd.DataFrame({'title':title_list, 'href':href_list, 'viewcount':clean_viewcount})
print(work_list)
# Out:
#                                                 title                  href  \
# 0   역대급 카(car)오스💦 PD한테 바람맞고 카메라 차단 당해서 강제 탐사보도 돼버린...  /watch?v=VpkfjLPjz3s
# 1   키즈카페가 그냥 커피라면 어린이집은 TOP야… 동심에 눈물폭발, 체력에 멘탈폭발, ...  /watch?v=Pw7w1_q3Q5M
# 22  [최초공개] 이제는 말할 수 있는 워크맨 채널의 충격 비화 공개합니다…💧 (feat...  /watch?v=9KfKfYHr1HY
# 23  ※장성규도 감당 불가 텐션※ 본격 취중 만담 엉망진창 대잔치 맥주 판촉 알바 리뷰🍺...  /watch?v=I8ohd4o0cvI
# 24  역대급 가’족’같은 분위기🏠 머리카락 대신 목 날아갈 뻔한 미용실 알바 리뷰ㅣ워크맨...  /watch?v=hSdwuOj2ecA
# 25                       [속보] “워크맨 채널 독립하자마자 파업 선언해…"  /watch?v=LESegodaX-c
# 26  🐜독립 채널🐜 직원들 꿀복지에 소개팅 트렌드 분석까지 ★갓벽★ 대환장 소개팅어플 회...  /watch?v=zeY3P0kPa0I
# 27  🐜독립 채널🐜(스포X) 어벤져스 스포 차단 꿀팁?! 영화관 알바 만렙이 말하는 알바...  /watch?v=gScLohLMiCA
# 28  🐜독립 채널🐜 홍대에 숨겨진 제2의 백종원 양성 학교?! 요리스킬 만렙 찍을 수 있...  /watch?v=ht0Zl9BJCwQ
# 29  🐜독립 채널🐜 ※야구덕후 주목※ 덕질하면서 돈 버는 덕업일치 끝판왕 알바는?!ㄷㄷ(...  /watch?v=SKsKdLNRDDk
# 30  🐜독립 채널🐜 ※충격※ 반도의 안 흔한 시급 17,000원짜리 알바..?! 공짜치킨...  /watch?v=A0as_-0ObgU
# 31  🐜독립 채널🐜 ※댓글 청정 주의※ 몸과 마음이 퓨어하다 못해 푸어...해짐★ 역대급...  /watch?v=QKTEbrFDbEc
# 32  🐜독립 채널🐜 사장님도 비추하는 극한 ★고깃집 알바★ 솔직 리뷰(ft.고기 잘 구우...  /watch?v=MnJqDkNwIsk
# 33  🐜독립 채널🐜 💵워크맨 사상 의외의 1등 시급 등장!!!💵 방학 단기 알바 끝판왕 ...  /watch?v=Das7SCjARAk
# 34  🐜독립 채널🐜 꿀알바인줄 알고 했다가 골로 갈뻔한 사연ㄷㄷ 여름철 극한 직업 죽음의...  /watch?v=DodhBgfzY_c
#
#     viewcount
# 0     3500000
# 1     4870000
# 2     5980000
# 3     2310000
# 4     5500000
# 5     6510000
# 6     6110000
# 7     5130000
# 8     7060000
# 9     6670000
# 10    7280000
# 11    7030000
# 12    2650000
# 13    7600000
# 14    6790000
# 15    8800000
# 16    7970000
# 17    8330000
# 18   10800000
# 19   13900000
# 20    9600000
# 21    7340000
# 22    1930000
# 23    6310000
# 24    8590000
# 25    3490000
# 26    5210000
# 27    4940000
# 28    6440000
# 29    2860000
# 30    5180000
# 31    4450000
# 32    4310000
# 33    3600000
# 34    4420000

# %%
work_list.head()
# Out:
#                                                title                  href  \
# 0  역대급 카(car)오스💦 PD한테 바람맞고 카메라 차단 당해서 강제 탐사보도 돼버린...  /watch?v=VpkfjLPjz3s
# 1  키즈카페가 그냥 커피라면 어린이집은 TOP야… 동심에 눈물폭발, 체력에 멘탈폭발, ...  /watch?v=Pw7w1_q3Q5M
# 2  하루에 람보르기니 40대 본다구요?;; 외제차 받고 한류 스타까지 더블로 영접한 청...  /watch?v=ol9PmyoIq24
# 3  길치가 배달알바하면 생기는 일.avi 🚫네비못봄, 경로이탈, 시간초과🚫 치킨 식혀서...  /watch?v=6NXzWfAHc_s
# 4  (영상에서 🍺 냄새남) 워크맨 최초 NO시급 NO업무 NO사장(?) 낭만뿜뿜 놀멍쉬...  /watch?v=v5MYPb_T4Co
#
#    viewcount
# 0    3500000
# 1    4870000
# 2    5980000
# 3    2310000
# 4    5500000

# %%
work_list.sort_values(by=['viewcount'], axis=0, ascending=False)
# Out:
#                                                 title                  href  \
# 19  🎉구독자 100만 기념 역대급 레전드🎉 인싸계 최종보스몹 에버랜드 알바 리뷰 1편 ...  /watch?v=UQYCWLrCUy4
# 18  ※기내 💊류 반입 금지※ 약 빤 장성규의 꿈의 직장★ 상큼터지는 항공사 직업 리뷰ㅣ...  /watch?v=m8JrVquHNsY
# 20  사장님도 모르는 피자 토핑 꿀조합... 🍕?! 루팡 클라스가 다른 천조국 피자집 알...  /watch?v=9OUaRBazbaQ
# 15  🎉200만 구독자 특집이 되어버린 에버랜드 2탄!! 🎉 역대급 초과근무에 파업 선언...  /watch?v=tQjfEFg1DR8
# 24  역대급 가’족’같은 분위기🏠 머리카락 대신 목 날아갈 뻔한 미용실 알바 리뷰ㅣ워크맨...  /watch?v=hSdwuOj2ecA
# 17  🔥구독자 요청 폭주🔥편돌이 시켰더니 먹방만 남아버린 국민 알바 편의점 알바 리뷰 ㅣ...  /watch?v=8NH2FBXUOt4
# 16  장성규 카트라이더 🌈무지개장갑썰 ㄹㅇ이었네? 놀면서 돈벌기 끝판王 게임회사 리뷰ㅣ워...  /watch?v=ufV7PIokoT0
# 13  비오면 X을 싼다고요...? 역대급 정신없음류 甲 난이도⭐️X100 대환장 술집 알...  /watch?v=KVGK856HUjE
# 21  JTBC로 돌아온 도비 장성규?! 오디오 빌 틈 1도 없는 녹즙 배달 인생 알바 리...  /watch?v=vZ-usD5ufSc
# 10  민속촌 보내놨더니 여기서도 아마존;; 구역 안 가리고 저세상드립 폭발해버린 민속촌 ...  /watch?v=aqpqoNk7GTs
# 8   *혈압주의* 옷가게 알바하다가 최악의 변태진상(손놈) 😈만난 썰;; 상상초월 의류매...  /watch?v=jEA3p1ekzSw
# 11  ⚠안전제일 ⚠ Job것들이 제일로 원했던 장성규의 고생길♥ 일하다가 5줌 쌀 뻔한 ...  /watch?v=RjGbCptFlFM
# 14  기어코 선 넘어버린 장성규...?! 아이돌 데뷔 각까지 잡는 덕후들의 성지 음악방송...  /watch?v=k5YaBcEBtGQ
# 9   🎉 300만 돌파 축하, 게드립 생선드립 다 모아봄🎉 해산물 제철 기념 날로 먹는 ...  /watch?v=bvN7YelS34A
# 5   잠시 쉬다오겠습니다... 포상휴가인 줄 알고 떠났다가 저세상 서비스하고 온 5성급 ...  /watch?v=W2Kpi5zDABE
# 28  🐜독립 채널🐜 홍대에 숨겨진 제2의 백종원 양성 학교?! 요리스킬 만렙 찍을 수 있...  /watch?v=ht0Zl9BJCwQ
# 23  ※장성규도 감당 불가 텐션※ 본격 취중 만담 엉망진창 대잔치 맥주 판촉 알바 리뷰🍺...  /watch?v=I8ohd4o0cvI
# 4     5500000
# 26    5210000
# 30    5180000
# 7     5130000
# 27    4940000
# 1     4870000
# 31    4450000
# 34    4420000
# 32    4310000
# 33    3600000
# 0     3500000
# 25    3490000
# 29    2860000
# 12    2650000
# 3     2310000
# 22    1930000

# %%
# 영상 본문 key(제목, 조회수, 좋아요, 싫어요, 본문내용, 전체 댓글 수) 추출 - 1
#################### 시간 소요 많음

title_num = 0;
n_title_list =[] # 영상별 제목 리스트 생성
story_sub_list = [] # 영상 본문내용 리스트
n_viewcount_list = [] #영상별 조회수 리스트 생성
n_like_list = [] #영상별 좋아요 리스트 생성
n_unlike_list = [] #영상별 싫어요 리스트 생성
n_date_list = [] #영상별 작성일 리스트 생성
n_href_list = [] # 영상별 주소 리스트 생성
start_url  = 'https://www.youtube.com/'

# 데이터
for i in href_list: # 
    url = start_url + i
    browser.get(url)
    print(i)  # 추출 주소값
    n_href_list.append(i)
    
    source = browser.page_source
    bs = BeautifulSoup(source, 'html.parser')
    bsstory = BeautifulSoup(source, "html.parser")
    
    
    # 영상에 대한 기본 정보 수집
    info1 = bs.find('div',{'id':'info-contents'})
    
    #n_title = "" #초기화 계속
    n_title = info1.find('h1',{'class':'title style-scope ytd-video-primary-info-renderer'}).text 
    n_title_list.append(n_title)
    n_viewcount =info1.find('yt-view-count-renderer',{'class':'style-scope ytd-video-primary-info-renderer'}).find_all('span')[0].text  
    n_viewcount_list.append(n_viewcount)
    n_like = info1.find('div',{'id':'top-level-buttons'}).find_all('yt-formatted-string')[0].text #좋아요수
    n_like_list.append(n_like)
    n_unlike = info1.find('div',{'id':'top-level-buttons'}).find_all('yt-formatted-string')[1].text 
    n_unlike_list.append(n_unlike)

    # 영상 본문 내용 추출
    story_sub = bsstory.find('yt-formatted-string', class_='content style-scope ytd-video-secondary-info-renderer').text
    story_sub_list.append(story_sub)
    title_num = title_num + 1; 
    #print(title_num, "번째 영상 본문 추출 끝")
    
# 리스트에 모두 입력되었는지 확인
print("제목: ", n_title_list)
print("조회수: ", n_viewcount_list)
print("좋아요: ", n_like_list)
print("싫어요: ",n_unlike_list)


# 조회수 데이터 전처리
clean_n_viewcount = []
for i in n_viewcount_list:
    a = i[4:-1]
    clean_n_viewcount.append(a)
print(clean_n_viewcount)

# 좋아요 데이터 전처리
clean_n_like_list = []
for i in n_like_list:
    if i[-1] == '만':
        a = i[:-1]
        amul = float(a)*10000
        clean_n_like_list.append(int(amul))
    elif i[-1] == '천':
        a = i[:-1]
        amul = float(a)*1000
        clean_n_unlike_list.append(int(amul))
    else:
        clean_n_like_list.append(i)
print(clean_n_like_list)

# 싫어요 데이터 전처리
clean_n_unlike_list = []
for i in n_unlike_list:
    if i[-1] == '천':
        a = i[:-1]
        amul = float(a)*1000
        clean_n_unlike_list.append(int(amul))
    else:
        clean_n_unlike_list.append(i)
print(clean_n_unlike_list)

#dataframe 생성
n_work_list = pd.DataFrame({'제목':n_title_list, '주소':n_href_list, '조회수':clean_n_viewcount,
                           '좋아요':clean_n_like_list, '싫어요':clean_n_unlike_list, '본문내용':story_sub_list})
이득!!★맥주보이★알바 리뷰ㅣ워크맨 ep.3', '🐜독립 채널🐜 ※댓글 청정 주의※ 몸과 마음이 퓨어하다 못해 푸어...해짐★ 역대급 극한 알바 키즈카페 리뷰ㅣ워크맨 ep.7', '🐜독립 채널🐜 사장님도 비추하는 극한 ★고깃집 알바★ 솔직 리뷰(ft.고기 잘 구우면 팁 쏟아짐)ㅣ워크맨 ep.4', '🐜독립 채널🐜 💵워크맨 사상 의외의 1등 시급 등장!!!💵 방학 단기 알바 끝판왕 전단지 알바 리뷰 (feat. 워크맨 채널 분리 예고ㅇㅇ)ㅣ워크맨 ep.9', '🐜독립 채널🐜 꿀알바인줄 알고 했다가 골로 갈뻔한 사연ㄷㄷ 여름철 극한 직업 죽음의 워터파크 알바 리뷰ㅣ워크맨 ep.5']
# 조회수:  ['조회수 3,502,113회', '조회수 4,871,856회', '조회수 5,981,947회', '조회수 2,314,560회', '조회수 5,504,379회', '조회수 6,512,828회', '조회수 6,117,576회', '조회수 5,131,126회', '조회수 7,067,246회', '조회수 6,671,293회', '조회수 7,280,418회', '조회수 7,031,247회', '조회수 2,658,057회', '조회수 7,607,960회', '조회수 6,799,630회', '조회수 8,807,643회', '조회수 7,975,835회', '조회수 8,335,762회', '조회수 10,800,382회', '조회수 13,900,600회', '조회수 9,606,757회', '조회수 7,340,495회', '조회수 1,934,767회', '조회수 6,314,599회', '조회수 8,591,252회', '조회수 3,495,254회', '조회수 5,216,086회', '조회수 4,941,991회', '조회수 6,449,778회', '조회수 2,865,275회', '조회수 5,184,334회', '조회수 4,456,119회', '조회수 4,316,593회', '조회수 3,605,889회', '조회수 4,426,332회']
# 좋아요:  ['5.7만', '7.7만', '10만', '2.8만', '9만', '8.9만', '8.2만', '9.1만', '9.3만', '11만', '11만', '11만', '5.4만', '9.7만', '9.6만', '14만', '12만', '10만', '13만', '18만', '10만', '8.7만', '2.9만', '7.3만', '9.5만', '7.1만', '4.4만', '4.3만', '5.4만', '2.3만', '3.9만', '4.4만', '4.8만', '4.3만', '4.5만']
# 싫어요:  ['1.1천', '1.3천', '1.4천', '779', '1.4천', '1.6천', '1.7천', '1.2천', '2.5천', '2.1천', '2.1천', '2.1천', '774', '2.4천', '1.5천', '2.3천', '2천', '3.6천', '3천', '3.1천', '2.3천', '1.4천', '310', '1.2천', '1.8천', '576', '1.1천', '945', '1.1천', '470', '876', '850', '851', '596', '809']
# ['3,502,113', '4,871,856', '5,981,947', '2,314,560', '5,504,379', '6,512,828', '6,117,576', '5,131,126', '7,067,246', '6,671,293', '7,280,418', '7,031,247', '2,658,057', '7,607,960', '6,799,630', '8,807,643', '7,975,835', '8,335,762', '10,800,382', '13,900,600', '9,606,757', '7,340,495', '1,934,767', '6,314,599', '8,591,252', '3,495,254', '5,216,086', '4,941,991', '6,449,778', '2,865,275', '5,184,334', '4,456,119', '4,316,593', '3,605,889', '4,426,332']
# [57000, 77000, 100000, 28000, 90000, 89000, 82000, 91000, 93000, 110000, 110000, 110000, 54000, 97000, 96000, 140000, 120000, 100000, 130000, 180000, 100000, 87000, 29000, 73000, 95000, 71000, 44000, 43000, 54000, 23000, 39000, 44000, 48000, 43000, 45000]
# [1100, 1300, 1400, '779', 1400, 1600, 1700, 1200, 2500, 2100, 2100, 2100, '774', 2400, 1500, 2300, 2000, 3600, 3000, 3100, 2300, 1400, '310', 1200, 1800, '576', 1100, '945', 1100, '470', '876', '850', '851', '596', '809']

# %%
n_work_list.head()
# Out:
#                                                   제목                    주소  \
# 0  역대급 카(car)오스💦 PD한테 바람맞고 카메라 차단 당해서 강제 탐사보도 돼버린...  /watch?v=VpkfjLPjz3s
# 1  키즈카페가 그냥 커피라면 어린이집은 TOP야… 동심에 눈물폭발, 체력에 멘탈폭발, ...  /watch?v=Pw7w1_q3Q5M
# 2  하루에 람보르기니 40대 본다구요?;; 외제차 받고 한류 스타까지 더블로 영접한 청...  /watch?v=ol9PmyoIq24
# 3  길치가 배달알바하면 생기는 일.avi 🚫네비못봄, 경로이탈, 시간초과🚫 치킨 식혀서...  /watch?v=6NXzWfAHc_s
# 4  (영상에서 🍺 냄새남) 워크맨 최초 NO시급 NO업무 NO사장(?) 낭만뿜뿜 놀멍쉬...  /watch?v=v5MYPb_T4Co
#
#          조회수     좋아요   싫어요                                               본문내용
# 0  3,502,113   57000  1100  JOB것들아~~~♥ 인력소장이다,,,,~~~😎😎😎\n운전하는 잡것덜~~~ 차는,,,...
# 1  4,871,856   77000  1300  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎\n진짜,,,,, 초등학교든,,...
# 2  5,981,947  100000  1400  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎\r\n주유소,,알바도~~항상 ...
# 3  2,314,560   28000   779  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎\n요즘,,,갑자기 화아아악,,...
# 4  5,504,379   90000  1400  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎\n히야아 요즘 내 동년배덜,,...

# %%
# 영상별 댓글 추출
title_num = 0;
youtube_pd = pd.DataFrame() # 영상 당 댓글 df 생성용
total_youtube_pd = pd.DataFrame() #최종 df 생성용
str_youtube_comments_len = [] # 영상별 댓글수 리스트 생성
 # 좋아요수 클리닝을 위한 리스트 생성

start_url  = 'https://www.youtube.com/'
for i in href_list: # :2 뺴면 전체 데이터, 시간 단축을 위해 2개 샘플만 시행
    url = start_url + i
    browser.get(url)  
    print(i)  # 추출 주소값
    source = browser.page_source
    bs = BeautifulSoup(source, "html.parser")

    ############################
    # 댓글 추출 코드
    reply_list = [] #댓글 리스트 생성
    body = browser.find_element_by_tag_name('body')#스크롤하기 위해 소스 추출
    num_of_pagedowns = 10

    #스크롤 다운
    while num_of_pagedowns:
        body.send_keys(Keys.PAGE_DOWN)
        num_of_pagedowns -= 1
    
        html0 = browser.page_source
        html = BeautifulSoup(html0,'html.parser')

        youtube_user_IDs = html.select('div#header-author > a > span')
        youtube_comments = html.select('yt-formatted-string#content-text')
        youtube_likes = html.select('div#toolbar > span')
    
        str_youtube_userIDs = []
        str_youtube_comments = []
        str_youtube_likes = []
        str_youtube_title_number = [] #영상 타이틀 넘버
             
    for i in range(len(youtube_user_IDs)):
        str_tmp = str(youtube_user_IDs[i].text)
        str_tmp = str_tmp.replace('\n', '')
        str_tmp = str_tmp.replace('\t', '')
        str_tmp = str_tmp.replace('               ','')
        str_youtube_userIDs.append(str_tmp)

        str_tmp = str(youtube_comments[i].text)
        str_tmp = str_tmp.replace('\n', '')
        str_tmp = str_tmp.replace('\t', '')
        str_tmp = str_tmp.replace('               ', '')
        str_youtube_comments.append(str_tmp)
    
        str_tmp = str(youtube_likes[i*2].text)
        str_tmp = str_tmp.replace('\n', '')
        str_tmp = str_tmp.replace('\t', '')
        str_tmp = str_tmp.replace('               ','')
        str_youtube_likes.append(str_tmp)
        
        # 어떤 영상인지 넘버링으로 확인
        str_youtube_title_number.append(title_num)
        #print("title_num: ", title_num) #테스트
        
        clean_str_youtube_likes = []
        # 좋아요수 전처리, 좋아요수가 str+공백으로 들어가 있어 공백 제거 후 계산
        for i in str_youtube_likes:
            i = i.replace(" ", '')
            if i.find('만') !=-1:
                a = i.replace('만', '')
                amul = float(a)*10000
                clean_str_youtube_likes.append(int(amul))
            elif i.find('천') != -1:
                a = i.replace('천', '')
                amul = float(a)*1000
                clean_str_youtube_likes.append(int(amul))
            else:
                clean_str_youtube_likes.append(int(i))
        
         # 리뷰 & 좋아요수 데이터 프레임 생성
        youtube_pd = pd.DataFrame({"ID":str_youtube_userIDs, "Comment":str_youtube_comments, 
                                   "Like":clean_str_youtube_likes, "Title_number":str_youtube_title_number})
    total_youtube_pd = pd.concat([total_youtube_pd, youtube_pd]) 
    print(len(youtube_pd))
    
    str_youtube_comments_len.append(len(youtube_pd))
# Out:
# /watch?v=VpkfjLPjz3s
# 20
#
# /watch?v=Pw7w1_q3Q5M
# 20
#
# /watch?v=ol9PmyoIq24
# 20
#
# /watch?v=6NXzWfAHc_s
# 20
#
# /watch?v=v5MYPb_T4Co
# 20
#
# /watch?v=W2Kpi5zDABE
# 20
#
# /watch?v=l502xg11uNM
# 20
#
# /watch?v=byjgWjqoCvw
# 20
#
# /watch?v=jEA3p1ekzSw
# 20
#
# /watch?v=bvN7YelS34A
# 20
#
# /watch?v=aqpqoNk7GTs
# 20
#
# /watch?v=RjGbCptFlFM
# 20
#
# /watch?v=JX3X5W8HylE
# 20
#
# /watch?v=KVGK856HUjE
# 20
#
# /watch?v=k5YaBcEBtGQ
# 20
#
# /watch?v=tQjfEFg1DR8
# 20
#
# /watch?v=ufV7PIokoT0
# 20
#
# /watch?v=8NH2FBXUOt4
# 20
#
# /watch?v=m8JrVquHNsY
# 20
#
# /watch?v=UQYCWLrCUy4
# 20
#
# /watch?v=9OUaRBazbaQ
# 20
#
# /watch?v=vZ-usD5ufSc
# 20
#
# /watch?v=9KfKfYHr1HY
# 20
#
# /watch?v=I8ohd4o0cvI
# 20
#
# /watch?v=hSdwuOj2ecA
# 20
#
# /watch?v=LESegodaX-c
# 20
#
# /watch?v=zeY3P0kPa0I
# 20
#
# /watch?v=gScLohLMiCA
# 20
#
# /watch?v=ht0Zl9BJCwQ
# 20
#
# /watch?v=SKsKdLNRDDk
# 20
#
# /watch?v=A0as_-0ObgU
# 20
#
# /watch?v=QKTEbrFDbEc
# 20
#
# /watch?v=MnJqDkNwIsk
# 20
#
# /watch?v=Das7SCjARAk
# 20
#
# /watch?v=DodhBgfzY_c
# 20
#
# * 본문 추출 개수:  35
# * 댓글 추출 개수:  35

# %%
print("* 본문 추출 개수: ", len(story_sub_list))   #추출한 본문 개수 확인
print("* 댓글 추출 개수: ", len(total_youtube_pd)) #추출한 댓글 개수 확인
# Out:
# * 본문 추출 개수:  35
# * 댓글 추출 개수:  700

# %%
print(str_youtube_comments_len)
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %%
#추출한 본문 예시 1개 확인
print("예시 1개", print(story_sub_list[0]))
# Out:
# JOB것들아~~~♥ 인력소장이다,,,,~~~😎😎😎
# 운전하는 잡것덜~~~ 차는,,, 타이어가 생명인거,,, 알제~~~ㅎ
# 펑크나면,,,~ 후딱후딱 바꾸러가고~~ 미루다가 큰일난다~~~!!
#
# 세상의 모든 job것들을리뷰한다 [워크맨]
# ▶ 매주 금 오후 6시공개
#
# #워크맨 #workman #장성규 #타이어 #넥센 #자동차
# #직업리뷰 #알바리뷰 #장성규 #스튜디오룰루랄라
# 예시 1개 None

# %%
# 본문내용 데이터 전처리
clean_story_sub_list = []
for i in range(len(story_sub_list)):
        str_tmp = str(story_sub_list[i])
        # print(str_tmp)
        str_tmp = str_tmp.replace('#', '')
        str_tmp = str_tmp.replace('\n', '')
        str_tmp = str_tmp.replace('\r', '')
        str_tmp = str_tmp.replace('세상의 모든 job것들을 리뷰한다 [워크맨]', '')
        str_tmp = str_tmp.replace('▶ 매주 금 오후 6시 공개','')
        str_tmp = str_tmp.replace('▶ 구독/좋아요/알람 설정','')
        str_tmp = str_tmp.replace('세상의 모든 job것들을리뷰한다 [워크맨]▶ 매주 금 오후 6시공개','')
        clean_story_sub_list.append(str_tmp)

print(clean_story_sub_list)
# Out:
# ['JOB것들아~~~♥ 인력소장이다,,,,~~~😎😎😎운전하는 잡것덜~~~ 차는,,, 타이어가 생명인거,,, 알제~~~ㅎ펑크나면,,,~ 후딱후딱 바꾸러가고~~ 미루다가 큰일난다~~~!! 워크맨 workman 장성규 타이어 넥센 자동차직업리뷰 알바리뷰 장성규 스튜디오룰루랄라', 'JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎진짜,,,,, 초등학교든,,,~중학교든~~ 어린이집이든!!!!선생님들 너~,,,무 대단하신거여,,, ,다들 리스펙~~~~~ 워크맨 workman 장성규 어린이집 어린이집교사직업리뷰 알바리뷰 장성규 스튜디오룰루랄라', 'JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎주유소,,알바도~~항상 안전이 젤 중요한거시다~~~,,,,알긋지~!?항상 불조심하고~~~차조심하고,,,,!!! 워크맨 workman 장성규 주유소알바 GS칼텍스직업리뷰 알바리뷰 장성규 스튜디오룰루랄라 엑소 EXO', 'JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎요즘,,,갑자기 화아아악,,, 추워져갖꼬~~~!! 집에서덜,, 배달 많이 시켜묵는디,,,배달하는 알바생덜,,,, 극한 직업이니께,,, 감사하다고~,,, 인사 한마디씩은 해주자고오~ 워크맨 workman 장성규 배달알바 배민 배달음식직업리뷰 알바리뷰 장성규 스튜디오룰루랄라', 'JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎히야아 요즘 내 동년배덜,,, 다 제주도 가믄 게스트하우스 간다더라고,,,,~~?울 잡것들도,,,~ 제주도서 게하체험해보구,~,,, 술은 너무 마니 마시지말고덜~~~!!!ㅎ 워크맨 workman 장성규 게하스탭 제주도직업리뷰 알바리뷰 장성규 스튜디오룰루랄라', 'JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 �
# %%
# 영상별 댓글수 추출
start_url  = 'https://www.youtube.com/'
#delay=0.1
#browser = Chrome()
#browser.implicitly_wait(delay)
str_n_comments = []

for i in href_list:#부하 방지용 인덱스
    url = start_url + i
    browser.get(url)
    print(i)  # 추출 주소값
    source = browser.page_source
    bs = BeautifulSoup(source, "html.parser")

    ############################
    # 댓글 추출 코드
    n_comment_list = [] #제목 리스트 생성
    body = browser.find_element_by_tag_name('body')#스크롤하기 위해 소스 추출
    num_of_pagedowns = 3
    
    #스크롤 다운
    while num_of_pagedowns:
        body.send_keys(Keys.PAGE_DOWN)
        num_of_pagedowns -= 1
    
        html0 = browser.page_source
        html = BeautifulSoup(html0,'html.parser')

        n_comments = html.select('div#title > h2 > yt-formatted-string')  
             
    for i in range(len(n_comments)):
        str_tmp = str(n_comments[i].text)
        str_tmp = str_tmp.replace('댓글 ', '')
        str_tmp = str_tmp.replace('개', '')
        str_n_comments.append(str_tmp) 
        print(str_tmp)
        print(str_n_comments)
# Out:
# /watch?v=VpkfjLPjz3s
# 5,182
# ['5,182']
# /watch?v=Pw7w1_q3Q5M
# 8,126
# ['5,182', '8,126']
# /watch?v=ol9PmyoIq24
# 8,400
# ['5,182', '8,126', '8,400']
# /watch?v=6NXzWfAHc_s
# 4,867
# ['5,182', '8,126', '8,400', '4,867']
# /watch?v=v5MYPb_T4Co
# 7,181
# ['5,182', '8,126', '8,400', '4,867', '7,181']
# /watch?v=W2Kpi5zDABE
# 6,543
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543']
# /watch?v=l502xg11uNM
# 4,690
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690']
# /watch?v=byjgWjqoCvw
# 6,836
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836']
# /watch?v=jEA3p1ekzSw
# 11,078
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078']
# /watch?v=bvN7YelS34A
# 12,458
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458']
# /watch?v=aqpqoNk7GTs
# 11,082
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082']
# /watch?v=RjGbCptFlFM
# 17,585
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585']
# /watch?v=JX3X5W8HylE
# 5,319
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319']
# /watch?v=KVGK856HUjE
# 7,766
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766']
# /watch?v=k5YaBcEBtGQ
# 7,845
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845']
# /watch?v=tQjfEFg1DR8
# 11,605
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605']
# /watch?v=ufV7PIokoT0
# 11,242
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242']
# /watch?v=8NH2FBXUOt4
# 12,722
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722']
# /watch?v=m8JrVquHNsY
# 13,511
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511']
# /watch?v=UQYCWLrCUy4
# 15,383
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383']
# /watch?v=9OUaRBazbaQ
# 7,583
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583']
# /watch?v=vZ-usD5ufSc
# 5,607
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607']
# /watch?v=9KfKfYHr1HY
# 1,833
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833']
# /watch?v=I8ohd4o0cvI
# 4,528
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528']
# /watch?v=hSdwuOj2ecA
# 7,234
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234']
# /watch?v=LESegodaX-c
# 3,277
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277']
# /watch?v=zeY3P0kPa0I
# 2,342
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342']
# /watch?v=gScLohLMiCA
# 3,370
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370']
# /watch?v=ht0Zl9BJCwQ
# 2,947
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947']
# /watch?v=SKsKdLNRDDk
# 955
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947', '955']
# /watch?v=A0as_-0ObgU
# 1,004
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947', '955', '1,004']
# /watch?v=QKTEbrFDbEc
# 2,424
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947', '955', '1,004', '2,424']
# /watch?v=MnJqDkNwIsk
# 1,579
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947', '955', '1,004', '2,424', '1,579']
# /watch?v=Das7SCjARAk
# 1,594
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947', '955', '1,004', '2,424', '1,579', '1,594']
# /watch?v=DodhBgfzY_c
# 1,626
# ['5,182', '8,126', '8,400', '4,867', '7,181', '6,543', '4,690', '6,836', '11,078', '12,458', '11,082', '17,585', '5,319', '7,766', '7,845', '11,605', '11,242', '12,722', '13,511', '15,383', '7,583', '5,607', '1,833', '4,528', '7,234', '3,277', '2,342', '3,370', '2,947', '955', '1,004', '2,424', '1,579', '1,594', '1,626']

# %%
# title, 주소, 조회수, 본문내용 추가한 데이터 프레임
work_list_update = pd.DataFrame({'제목':n_title_list, '주소':n_href_list, '조회수':clean_n_viewcount,
                          '좋아요':clean_n_like_list, '싫어요':clean_n_unlike_list, '댓글수':str_n_comments, '본문내용':clean_story_sub_list})

print(len(n_title_list))
print(len(n_href_list))
print(len(clean_n_viewcount))
print(len(clean_n_like_list))
print(len(clean_n_unlike_list))
print(len(str_n_comments))
print(len(clean_story_sub_list))

work_list_update.head()
# Out:
# 35
# 35
# 35
# 35
# 35
# 35
# 35
#                                                   제목                    주소  \
# 0  역대급 카(car)오스💦 PD한테 바람맞고 카메라 차단 당해서 강제 탐사보도 돼버린...  /watch?v=VpkfjLPjz3s
# 1  키즈카페가 그냥 커피라면 어린이집은 TOP야… 동심에 눈물폭발, 체력에 멘탈폭발, ...  /watch?v=Pw7w1_q3Q5M
# 2  하루에 람보르기니 40대 본다구요?;; 외제차 받고 한류 스타까지 더블로 영접한 청...  /watch?v=ol9PmyoIq24
# 3  길치가 배달알바하면 생기는 일.avi 🚫네비못봄, 경로이탈, 시간초과🚫 치킨 식혀서...  /watch?v=6NXzWfAHc_s
# 4  (영상에서 🍺 냄새남) 워크맨 최초 NO시급 NO업무 NO사장(?) 낭만뿜뿜 놀멍쉬...  /watch?v=v5MYPb_T4Co
#
#          조회수     좋아요   싫어요    댓글수  \
# 0  3,502,113   57000  1100  5,182
# 1  4,871,856   77000  1300  8,126
# 2  5,981,947  100000  1400  8,400
# 3  2,314,560   28000   779  4,867
# 4  5,504,379   90000  1400  7,181
#
#                                                 본문내용
# 0  JOB것들아~~~♥ 인력소장이다,,,,~~~😎😎😎운전하는 잡것덜~~~ 차는,,, 타...
# 1  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎진짜,,,,, 초등학교든,,,~...
# 2  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎주유소,,알바도~~항상 안전이 ...
# 3  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎요즘,,,갑자기 화아아악,,, ...
# 4  JOB것들아~~~♥ 인력소장이다,,,,~~~😎 😎 😎히야아 요즘 내 동년배덜,,, ...

# %%
# 0번째 영상에서 추출한 댓글 DataFrame
youtube_pd.head()
# Out:
#                            ID  \
# 0   워크맨-Workman
# 1        HS Kim
# 2            김준
# 3    Gray oasis
# 4        행복사랑부자
#
#                                              Comment   Like  Title_number
# 0  🐜🐜워크맨 인력소🐜🐜\r워크맨의 리뷰를 원하는 job것이 있다면↓댓글 추천↓\r\r...   1900             0
# 1  여직원 왜? 일 잘하는 거 같은데... 예의없는것도 아니고 워터파크는 삐끗하면 사고...  13000             0
# 2  워터파크 크기와 수준에 비해 청소용품 관련이 너무 열악한거 같다. 놀램. 저 정도의...   7400             0
# 3  아니ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ군대...  11000             0
# 4  미끄럼틀 닦는데 그 큰 면적을 저 작은 수건으로 닦는다고....?청소도구를 바꾸던지...   3600             0

# %%
# 전체 영상에서 추출한 댓글 DataFrame
total_youtube_pd
# Out:
#                                          ID  \
# 0                 워크맨-Workman
# 1    잡코리아USA - 알면 쉬운 미국 취업 TV
# 2                         김성희
# 3                          인서
# 4                       탱귤 탱귤
# 5            밍밍이들- 동네핫플이 궁금해?
# 6                         W H
# 7                        유사인간
# 8                  개시바하면짖는시바개
# 9                      주네JUNE
# 10             한국민속촌 춘삼이는 꽃거지
# 11                        심수연
# 12              PARK KYUNGTAE
# 13                        ㅈH현
# 14                gygygy hong
# 15                 생갈치1호의행방불명
# 16       윤아나 월드 Yoonana World
# 17                         이한
# 18                        허지은
# 19                  Yujin Lee
# 0                 워크맨-Workman
# 1                         목베개
# 2                         마이쮸
# 3                         김지지
# 4                       비옹비옹.
# 5                         사나래
# 6                 윤블리Yoonvely
# 7                        일일일오
# 8                       펭수의참치
# 9                         주언이
# ..                                      ...
# 10                    VIDEO K
# 11                        신승호
# 12           progamers hybrid
# 13                        권혁준
# 14                      C ris
# 15                      파카알파카
# 16                [지니어스]쿠앙 뺀슬
# 17                    you ooo
# 18                  doit just
# 19                        정병선
# 0                 워크맨-Workman
# 1                      HS Kim
# 2                          김준
# 3                  Gray oasis
# 4                      행복사랑부자
# 5                  후쿠티비 쇼핑몰놈들
# 6                         브이V
# 7                         귭만찢
# 8                        Dino
# 9                이미터용TV [김진용]
# 10        Simon Seungwon Choi
# 11            Amber Rodriguez
# 12                        이정식
# 13                  Ebony Kim
# 14                         김준
# 15                         퐁에
# 16                     sh god
# 17            Amber Rodriguez
# 18                    rin cha
# 19       빠나나나나빠나나나빠나나나나빠나나나나나
#
#                                               Comment   Like  Title_number
# 0   JOB것들아~~~♥ 인력소장이다,,,,~~~😎😎😎이번에는,,,특이한,,,~ 알바 시...   7400             0
# 1   민속촌 갑분툭  일하는거 겁나 웃기네 ㅋㅋㅋㅋㅋ 끝난거지 는 또 뭐야 ㅋㅋㅋㅋㅋㅋㅋ...   3800             0
# 2   ㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋ아니 민속촌 알바하시는 분들은 왜 친절하게 도와주시는 건데ㅋㅋㅌㅋ...   2400             0
# 3   아 저분이 저번에 신서유기에서 피카추 탱그탑 입으셨던 분이신가?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...   1300             0
# 4   구독자가 왜 장성규를 모르는거얔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 미친 편집에 과하지도 않고 ...    551             0
# 14         더우신대도 할머님들 알바전단지 열심히 돌리시는모습보고 감동입니다 힘내세요!!    584             0
# 15  솔직히 전단지알바는 어머님들 쓰는 게 가장 좋음개같은 급딱 새기들이 전단지 돌리기 ...     85             0
# 16                    할머니분둘이 전단디알바 하는거 보니까 마음이 아푸다무ㅜㅜ    593             0
# 17  아닠ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ애초에 이 컨텐츠 볼때마다 편집도 편집인데 장성규가 웬만한 개...   6200             0
# 18           나만 이자카야->이작가 웃김? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 이작가 런치입니다~    432             0
# 19  성규형 진짜 드립이 너무 좋아요기분나쁘지않을만큼의 깐족과 깔끔한 드립채널분리부터 우...    581             0
# 0   🐜🐜워크맨 인력소🐜🐜\r워크맨의 리뷰를 원하는 job것이 있다면↓댓글 추천↓\r\r...   1900             0
# 1   여직원 왜? 일 잘하는 거 같은데... 예의없는것도 아니고 워터파크는 삐끗하면 사고...  13000             0
# 2   워터파크 크기와 수준에 비해 청소용품 관련이 너무 열악한거 같다. 놀램. 저 정도의...   7400             0
# 3   아니ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ군대...  11000             0
# 4   미끄럼틀 닦는데 그 큰 면적을 저 작은 수건으로 닦는다고....?청소도구를 바꾸던지...   3600             0
# 5             담당 선배여자분 워크맨 시리즈중 프로페셔널한편에 속하는거 같은데....   4000             0
# 6   차라리 걸레로 닦지말고 원통모양에 맞는 걸레를 제작해서ㅈ 튜브뒤에 매달고 내려가는게...   3100             0
# 7      선배가 예민할 수밖에 없는 게... 안전상 이유로도 그렇고 예민할 수밖에 옶음...   4300             0
# 8     슬라이드 걸레로 손으로 닦는거 완전 오바다저 모양에 맞는 걸레 하나 제작안하냐 ㅡ.ㅡ   1200             0
# 9           선넘는 드립 칠 때마다 휙 넘어가버리는거 너무 웃기잖앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ   5000             0
# 10  워터슬라이드타면서 먼지잇는지 보고 컴플레인.거는.사람들은 정말...대단하다  한국컴...   1000             0
# 11        “Hold my speedo” HAHAH WHO MAKES THIS EDITS      2             0
# 12                            01:16 희미의 취미할때 표정보소 ㅋㅋㅋ   3800             0
# 13  왜.... 선배 웃기고 좋은데....... 꼭 다 웃으면서 항상 친절해야되는건 아니...   2200             0
# 14                        해병대 나오셨어요? 저는 그냥 4년제..ㅋㅋㅋㅋ😁   5400             0
# 15                  여직원분 매니저님인데...관리자중에 2번째로 높으신분임...    545             0
# 16           5:00 와 카메라 스태프 프로다 프로 ㅋㅋㅋㅋ 흔들림없이 내려오네 ㅋㅋ   1700             0
# 17  When he finds out there’s an employee elevator...      1             0
# 18  워터파크 스키장 같은데서 일하시는분들은 보통 체대출신도 많고 운동하신분들이 많습니다...    626             0
# 19                                 여자분 너무 멋있다 13년차 ㄷㄷ    542             0
#
# [700 rows x 4 columns]

# %%
# 워크맨 intro csv 저장
intro_df.to_csv("work_intro.csv", mode='w', encoding="utf-8-sig")

# 워크맨 동영상 csv 저장
work_list_update.to_csv("work.csv", mode='w', encoding="utf-8-sig")

# 워크맨 댓글 csv 저장
total_youtube_pd.to_csv("work_reply.csv", mode='w', encoding="utf-8-sig")
